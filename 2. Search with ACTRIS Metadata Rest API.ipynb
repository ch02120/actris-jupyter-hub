# %% [markdown]
# <img src='https://www.actris.eu/sites/default/files/inline-images/Actris%20logo.png' width=200 align=right>
#
# # ACTRIS DC
# ## Search with ACTRIS Metadata Rest API

# %% [markdown]
# ## Using ACTRIS metadata catalog REST API
#
# Using the ACTRIS REST API you can access all ACTRIS metadata, stations, instruments, networks etc. It is possible to get the full metadata archive at once, but(!) this can take a bit of time.
#
# ACTRIS Rest API documentation: https://prod-actris-md.nilu.no/index.html
#
# For the latest version including the metadata schema for model data, you would need to look here: https://dev-actris-md.nilu.no/index.html

# %%
# import packages

import pandas as pd
import requests
import json
import ipywidgets as widgets

# %% [markdown]
# ## Browse the metadata archive
#
# This is an example of how to browse and get used to the ACTRIS Rest API metadata catalog and each search element. Some of the most used metadata elements in the the ACTRIS metadata catalog is displayed with all values as dropdown widgets.

# %%
# Countries 

response = requests.get("https://prod-actris-md.nilu.no/Countries") # get all countries in metadata archive
archive = response.json()
df = pd.DataFrame(archive)

# dropdown widget 
dropdown_countries = widgets.Dropdown(
    options=list(df['en_name']),
    value=list(df['en_name'])[0],
    description='Countries:',
    disabled=False,
)

display(dropdown_countries)
# Out:
# Dropdown(description='Countries:', options=('Andorra', 'United Arab Emirates', 'Afghanistan', 'Antigua and Bar…

# %%
# Facilities

response = requests.get("https://prod-actris-md.nilu.no/Facilities")  # get all Facilities in metadata archive
archive = response.json()
df = pd.DataFrame(archive)

# dropdown widget 
dropdown_facilities = widgets.Dropdown(
    options=list(df['name']),
    value=list(df['name'])[0],
    description='Facilities:',
    disabled=False,
    
)

display(dropdown_facilities)
# Out:
# Dropdown(description='Facilities:', options=('PACS-C2 - Main site', 'Turbulent Leipzig Aerosol Cloud Interacti…

# %%
# Show facility chosen in dropdown menu
df[df['name']==dropdown_facilities.value]
# Out:
#    num_id            identifier                 name     lat    lon    alt
# 0     126  actris.chamber.ch.85  PACS-C2 - Main site  47.539  8.229  335.0  \
#
#   country_code wmo_region identifier_type
# 0           CH       None       other PID  \
#
#                                                  uri
# 0  https://actris-nf-labelling.out.ocp.fmi.fi/fac...

# %%
# show all metadata for norwegian facilities 
facilities_norway = df[df['country_code']=='NO'] #select norwegian facilities
facilities_norway # show archive as table
# Out:
#      num_id                  identifier                  name     lat    lon
# 114     141  actris.observational.no.59  Birkenes - Main site  58.388  8.252  \
#
#        alt country_code wmo_region identifier_type
# 114  219.0           NO       None       other PID  \
#
#                                                    uri
# 114  https://actris-nf-labelling.out.ocp.fmi.fi/fac...

# %%
response = requests.get("https://prod-actris-md.nilu.no/Providers") # get all networks in metadata archive
archive = response.json()
df = pd.DataFrame(archive)

# dropdown widget
dropdown_providers = widgets.Dropdown(
    options=list(df['name']),
    value=list(df['name'])[0],
    description='Providers:',
    disabled=False,
)

display(dropdown_providers)
# Out:
# Dropdown(description='Providers:', options=('admin', 'Norwegian Institute for Air Research', 'DVAS', 'ARES', '…

# %%
df[df['name']==dropdown_providers.value]
# Out:
#    id  name acronym                                        description
# 3  10  ARES    ARES  ACTRIS Aerosol remote sensing data centre unit...  \
#
#                         created
# 3  2020-06-29T07:05:07.4936990Z

# %% [markdown]
# ## Accessing metadata
#
# The full ACTRIS metadata catalog can be accessed with https://prod-actris-md.nilu.no/Metadata/, but(!) this can take a bit of time. Therefore its best search using the available search elements such as instrument, country, station, provider etc. Examples of this is shown under.

# %%
# get all metadata for a spesific instrument and country, here a dmps instrument in Norway
# response = requests.get("https://prod-actris-md.nilu.no/Metadata/instrument/dmps/country/NO") 
# metadata_archive = response.json() 

# get all metadata in catalogue (right now only ACTRIS NRT data)
response = requests.get("https://prod-actris-md.nilu.no/Metadata/") 
metadata_archive = response.json()

# %%
metadata_archive # show metadata
# Out:
# [{'md_metadata': {'id': 38,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://prod-actris-md.nilu.no/Providers/14'},
#    'file_identifier': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/FR0020R.20230530130000.20230815164002.filter_absorption_photometer...11w.1h.FR01L_Magee_AE33_SIR_pm1_NRT.FR01L_Magee_AE33_SIR.lev1.5.nc',
#    'language': 'en',
#    'hierarchy_level': 'nonGeographicDataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2023-08-15T14:40:02.0000000Z',
#    'created': '2023-09-14T11:14:33.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'mf@nilu.no',
#      'position_name': 'Senior scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of filter_absorption_photometer at SIRTA Atmospheric Research Observatory (FR0020R). These measurements are gathered as a part of the following projects ACTRIS_NRT, GAW-WDCA_NRT, RI-URBANS_NRT and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: aerosol_absorption_coefficient in pm1, aerosol_absorption_coefficient in pm1, aerosol_absorption_coefficient in pm1',
#    'title': 'Ground based in situ observations of filter_absorption_photometer at SIRTA Atmospheric Research Observatory (FR0020R)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Jean-Eudes',
#      'last_name': 'Petit',
#      'organisation_name': 'Not available',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'FR'},
#     {'first_name': 'Olivier',
#      'last_name': 'Favez',
#      'organisation_name': 'Not available',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'FR'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'fr0020r.20230530130000.20230815164002.filter_absorption_photometer...11w.1h.fr01l_magee_ae33_sir_pm1_nrt.fr01l_magee_ae33_sir.lev1.5.nc',
#     'type': 'other PID'},
#    'date': '2023-08-15T14:40:02.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'otherRestrictions',
#    'data_licence': 'https://creativecommons.org/licenses/by/4.0/',
#    'metadata_licence': 'https://creativecommons.org/licenses/by/4.0/'},
#   'md_keywords': {'keywords': ['actris_nrt',
#     'aerosol_absorption_coefficient',
#     'atmospheric',
#     'fr0020r',
#     'gaw-wdca_nrt',
#     'observatory',
#     'pm1',
#     'research',
#     'ri-urbans_nrt',
#     'sirta']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': 'actris.observational.fr.27',
#     'name': 'SIRTA - Palaiseau',
#     'lat': 48.717,
#     'lon': 2.207,
#     'alt': 160.0,
#     'country_code': 'FR',
#     'wmo_region': None,
#     'identifier_type': 'other PID',
#     'uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/37'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 2.158888888888889,
#    'east_bound_longitude': 2.158888888888889,
#    'south_bound_latitude': 48.70861111111111,
#    'north_bound_latitude': 48.70861111111111},
#   'ex_temporal_extent': {'time_period_begin': '2023-05-30T11:00:00.0000000Z',
#    'time_period_end': '2023-08-15T02:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 162.0,
#    'maximum_value': 162.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['aerosol particle light absorption coefficient'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/FR0020R.20230530130000.20230815164002.filter_absorption_photometer...11w.1h.FR01L_Magee_AE33_SIR_pm1_NRT.FR01L_Magee_AE33_SIR.lev1.5.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/actris_nrt/FR0020R.20230530130000.20230815164002.filter_absorption_photometer...11w.1h.FR01L_Magee_AE33_SIR_pm1_NRT.FR01L_Magee_AE33_SIR.lev1.5.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['in situ particle optical parameter instrument'],
#    'program_affiliation': ['ACTRIS', 'GAW-WDCA', 'RI-URBANS'],
#    'variable_statistical_property': ['geometric standard deviation',
#     'linear standard deviation'],
#    'legacy_data': True,
#    'observation_timeliness': 'near real-time',
#    'data_product': 'near-realtime data'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS associated'}},
#  {'md_metadata': {'id': 39,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://prod-actris-md.nilu.no/Providers/14'},
#    'file_identifier': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/FR0020R.20230511110000.20230811094802.filter_absorption_photometer...3mo.1h.FR01L_Magee_AE33_SIR_pm10_NRT.FR01L_Magee_AE33_SIR.lev1.5.nc',
#    'language': 'en',
#    'hierarchy_level': 'nonGeographicDataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2023-08-11T07:48:02.0000000Z',
#    'created': '2023-09-14T11:14:33.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'mf@nilu.no',
#      'position_name': 'Senior scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of filter_absorption_photometer at SIRTA Atmospheric Research Observatory (FR0020R). These measurements are gathered as a part of the following projects ACTRIS_NRT, GAW-WDCA_NRT, RI-URBANS_NRT and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: aerosol_absorption_coefficient in pm10, aerosol_absorption_coefficient in pm10, aerosol_absorption_coefficient in pm10',
#    'title': 'Ground based in situ observations of filter_absorption_photometer at SIRTA Atmospheric Research Observatory (FR0020R)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Jean-Eudes',
#      'last_name': 'Petit',
#      'organisation_name': 'Not available',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'FR'},
#     {'first_name': 'Olivier',
#      'last_name': 'Favez',
#      'organisation_name': 'Not available',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'FR'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'fr0020r.20230511110000.20230811094802.filter_absorption_photometer...3mo.1h.fr01l_magee_ae33_sir_pm10_nrt.fr01l_magee_ae33_sir.lev1.5.nc',
#     'type': 'other PID'},
#    'date': '2023-08-11T07:48:02.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'otherRestrictions',
#    'data_licence': 'https://creativecommons.org/licenses/by/4.0/',
#    'metadata_licence': 'https://creativecommons.org/licenses/by/4.0/'},
#   'md_keywords': {'keywords': ['actris_nrt',
#     'aerosol_absorption_coefficient',
#     'atmospheric',
#     'fr0020r',
#     'gaw-wdca_nrt',
#     'observatory',
#     'pm10',
#     'research',
#     'ri-urbans_nrt',
#     'sirta']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': 'actris.observational.fr.27',
#     'name': 'SIRTA - Palaiseau',
#     'lat': 48.717,
#     'lon': 2.207,
#     'alt': 160.0,
#     'country_code': 'FR',
#     'wmo_region': None,
#     'identifier_type': 'other PID',
#     'uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/37'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 2.158888888888889,
#    'east_bound_longitude': 2.158888888888889,
#    'south_bound_latitude': 48.70861111111111,
#    'north_bound_latitude': 48.70861111111111},
#   'ex_temporal_extent': {'time_period_begin': '2023-05-11T09:00:00.0000000Z',
#    'time_period_end': '2023-08-11T07:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 162.0,
#    'maximum_value': 162.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['aerosol particle light absorption coefficient'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/FR0020R.20230511110000.20230811094802.filter_absorption_photometer...3mo.1h.FR01L_Magee_AE33_SIR_pm10_NRT.FR01L_Magee_AE33_SIR.lev1.5.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/actris_nrt/FR0020R.20230511110000.20230811094802.filter_absorption_photometer...3mo.1h.FR01L_Magee_AE33_SIR_pm10_NRT.FR01L_Magee_AE33_SIR.lev1.5.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['in situ particle optical parameter instrument'],
#    'program_affiliation': ['ACTRIS', 'GAW-WDCA', 'RI-URBANS'],
#    'variable_statistical_property': ['geometric standard deviation',
#     'linear standard deviation'],
#    'legacy_data': True,
#    'observation_timeliness': 'near real-time',
#    'data_product': 'near-realtime data'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS associated'}},
#  {'md_metadata': {'id': 35,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://prod-actris-md.nilu.no/Providers/14'},
#    'file_identifier': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/RO0010R.20230614050000.20230914050634.filter_absorption_photometer...3mo.1h.RO03L_Magee_AE33_INO_NRT.RO03L_AE33.lev1.5.nc',
#    'language': 'en',
#    'hierarchy_level': 'nonGeographicDataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2023-09-14T03:06:34.0000000Z',
#    'created': '2023-09-14T11:14:29.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'mf@nilu.no',
#      'position_name': 'Senior scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of filter_absorption_photometer at RADO-Bucharest II (RO0010R). These measurements are gathered as a part of the following projects ACTRIS_NRT, GAW-WDCA_NRT, RI-URBANS_NRT and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: aerosol_absorption_coefficient in pm10, aerosol_absorption_coefficient in pm10, aerosol_absorption_coefficient in pm10',
#    'title': 'Ground based in situ observations of filter_absorption_photometer at RADO-Bucharest II (RO0010R)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Bucharest',
#      'last_name': 'RADO',
#      'organisation_name': 'National Institute of Research and Development for Optoelectronics',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'RO'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'ro0010r.20230614050000.20230914050634.filter_absorption_photometer...3mo.1h.ro03l_magee_ae33_ino_nrt.ro03l_ae33.lev1.5.nc',
#     'type': 'other PID'},
#    'date': '2023-09-14T03:06:34.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'otherRestrictions',
#    'data_licence': 'https://creativecommons.org/licenses/by/4.0/',
#    'metadata_licence': 'https://creativecommons.org/licenses/by/4.0/'},
#   'md_keywords': {'keywords': ['actris_nrt',
#     'aerosol_absorption_coefficient',
#     'gaw-wdca_nrt',
#     'ii',
#     'pm10',
#     'rado-bucharest',
#     'ri-urbans_nrt',
#     'ro0010r']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': 'actris.observational.ro.67',
#     'name': 'RADO-Bucharest - RADO',
#     'lat': 44.348,
#     'lon': 26.029,
#     'alt': 93.0,
#     'country_code': 'RO',
#     'wmo_region': None,
#     'identifier_type': 'other PID',
#     'uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/99'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 26.012,
#    'east_bound_longitude': 26.012,
#    'south_bound_latitude': 44.344,
#    'north_bound_latitude': 44.344},
#   'ex_temporal_extent': {'time_period_begin': '2023-06-14T03:00:00.0000000Z',
#    'time_period_end': '2023-09-14T03:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 77.0,
#    'maximum_value': 77.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['aerosol particle light absorption coefficient'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/RO0010R.20230614050000.20230914050634.filter_absorption_photometer...3mo.1h.RO03L_Magee_AE33_INO_NRT.RO03L_AE33.lev1.5.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/actris_nrt/RO0010R.20230614050000.20230914050634.filter_absorption_photometer...3mo.1h.RO03L_Magee_AE33_INO_NRT.RO03L_AE33.lev1.5.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['in situ particle optical parameter instrument'],
#    'program_affiliation': ['ACTRIS', 'GAW-WDCA', 'RI-URBANS'],
#    'variable_statistical_property': ['geometric standard deviation',
#     'linear standard deviation'],
#    'legacy_data': True,
#    'observation_timeliness': 'near real-time',
#    'data_product': 'near-realtime data'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS associated'}},
#  {'md_metadata': {'id': 37,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://prod-actris-md.nilu.no/Providers/14'},
#    'file_identifier': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/GR0100B.20230614050000.20230914051039.filter_absorption_photometer...3mo.1h.GR05L_Magee_AE33_DEM_dry_NRT.GR05L_abs_coef_AE33_v1.lev1.5.nc',
#    'language': 'en',
#    'hierarchy_level': 'nonGeographicDataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2023-09-14T03:10:39.0000000Z',
#    'created': '2023-09-14T11:14:32.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'mf@nilu.no',
#      'position_name': 'Senior scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of filter_absorption_photometer at DEM_Athens (GR0100B). These measurements are gathered as a part of the following projects ACTRIS_NRT, RI-URBANS_NRT and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: aerosol_absorption_coefficient in aerosol (volume_absorption_coefficient_in_air_due_to_dried_aerosol_particles), aerosol_absorption_coefficient in aerosol (volume_absorption_coefficient_in_air_due_to_dried_aerosol_particles), aerosol_absorption_coefficient in aerosol (volume_absorption_coefficient_in_air_due_to_dried_aerosol_particles)',
#    'title': 'Ground based in situ observations of filter_absorption_photometer at DEM_Athens (GR0100B)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Konstantinos',
#      'last_name': 'Eleftheriadis',
#      'organisation_name': 'Not available',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'GR'},
#     {'first_name': 'Stergios',
#      'last_name': 'Vratolis',
#      'organisation_name': 'Not available',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'GR'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'gr0100b.20230614050000.20230914051039.filter_absorption_photometer...3mo.1h.gr05l_magee_ae33_dem_dry_nrt.gr05l_abs_coef_ae33_v1.lev1.5.nc',
#     'type': 'other PID'},
#    'date': '2023-09-14T03:10:39.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'otherRestrictions',
#    'data_licence': 'https://creativecommons.org/licenses/by/4.0/',
#    'metadata_licence': 'https://creativecommons.org/licenses/by/4.0/'},
#   'md_keywords': {'keywords': ['actris_nrt',
#     'aerosol',
#     'aerosol_absorption_coefficient',
#     'dem_athens',
#     'gr0100b',
#     'ri-urbans_nrt',
#     'volume_absorption_coefficient_in_air_due_to_dried_aerosol_particles']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': 'actris.observational.gr.49',
#     'name': 'Athens Supersite Demokritos - Main site',
#     'lat': 37.995,
#     'lon': 23.816,
#     'alt': 270.0,
#     'country_code': 'GR',
#     'wmo_region': None,
#     'identifier_type': 'other PID',
#     'uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/71'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 23.8159999847,
#    'east_bound_longitude': 23.8159999847,
#    'south_bound_latitude': 37.9949989319,
#    'north_bound_latitude': 37.9949989319},
#   'ex_temporal_extent': {'time_period_begin': '2023-06-14T03:00:00.0000000Z',
#    'time_period_end': '2023-09-14T03:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 270.0,
#    'maximum_value': 270.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['aerosol particle light absorption coefficient'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/GR0100B.20230614050000.20230914051039.filter_absorption_photometer...3mo.1h.GR05L_Magee_AE33_DEM_dry_NRT.GR05L_abs_coef_AE33_v1.lev1.5.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/actris_nrt/GR0100B.20230614050000.20230914051039.filter_absorption_photometer...3mo.1h.GR05L_Magee_AE33_DEM_dry_NRT.GR05L_abs_coef_AE33_v1.lev1.5.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['in situ particle optical parameter instrument'],
#    'program_affiliation': ['ACTRIS', 'RI-URBANS'],
#    'variable_statistical_property': ['geometric standard deviation',
#     'linear standard deviation'],
#    'legacy_data': True,
#    'observation_timeliness': 'near real-time',
#    'data_product': 'near-realtime data'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS associated'}},
#  {'md_metadata': {'id': 47,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://prod-actris-md.nilu.no/Providers/14'},
#    'file_identifier': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/ES0020U.20230614050000.20230914043809.nephelometer..aerosol.3mo.1h.ES08L_TSI_3563_UGR_NRT.ES08L_scat_coef.lev1.5.nc',
#    'language': 'en',
#    'hierarchy_level': 'nonGeographicDataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2023-09-14T02:38:09.0000000Z',
#    'created': '2023-09-14T11:14:40.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'mf@nilu.no',
#      'position_name': 'Senior scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of nephelometer at Granada (ES0020U). These measurements are gathered as a part of the following projects ACTRIS_NRT, GAW-WDCA_NRT, NOAA-ESRL_NRT and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: aerosol_light_backscattering_coefficient in aerosol (volume_backwards_scattering_coefficient_in_air_due_to_dried_aerosol_particles), aerosol_light_backscattering_coefficient in aerosol (volume_backwards_scattering_coefficient_in_air_due_to_dried_aerosol_particles), aerosol_light_backscattering_coefficient in aerosol (volume_backwards_scattering_coefficient_in_air_due_to_dried_aerosol_particles), aerosol_light_scattering_coefficient in aerosol (volume_scattering_coefficient_in_air_due_to_dried_aerosol_particles), aerosol_light_scattering_coefficient in aerosol (volume_scattering_coefficient_in_air_due_to_dried_aerosol_particles), aerosol_light_scattering_coefficient in aerosol (volume_scattering_coefficient_in_air_due_to_dried_aerosol_particles)',
#    'title': 'Ground based in situ observations of nephelometer at Granada (ES0020U)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Lucas',
#      'last_name': 'Alados-Arboledas',
#      'organisation_name': 'Not available',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'ES'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'es0020u.20230614050000.20230914043809.nephelometer..aerosol.3mo.1h.es08l_tsi_3563_ugr_nrt.es08l_scat_coef.lev1.5.nc',
#     'type': 'other PID'},
#    'date': '2023-09-14T02:38:09.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'otherRestrictions',
#    'data_licence': 'https://creativecommons.org/licenses/by/4.0/',
#    'metadata_licence': 'https://creativecommons.org/licenses/by/4.0/'},
#   'md_keywords': {'keywords': ['actris_nrt',
#     'aerosol',
#     'aerosol_light_backscattering_coefficient',
#     'aerosol_light_scattering_coefficient',
#     'es0020u',
#     'gaw-wdca_nrt',
#     'granada',
#     'noaa-esrl_nrt',
#     'volume_backwards_scattering_coefficient_in_air_due_to_dried_aerosol_particles',
#     'volume_scattering_coefficient_in_air_due_to_dried_aerosol_particles']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': 'actris.observational.es.77',
#     'name': 'Granada - Main site',
#     'lat': 37.2,
#     'lon': -3.6,
#     'alt': 680.0,
#     'country_code': 'ES',
#     'wmo_region': None,
#     'identifier_type': 'other PID',
#     'uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/110'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': -3.605,
#    'east_bound_longitude': -3.605,
#    'south_bound_latitude': 37.164,
#    'north_bound_latitude': 37.164},
#   'ex_temporal_extent': {'time_period_begin': '2023-06-14T03:00:00.0000000Z',
#    'time_period_end': '2023-09-14T01:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 680.0,
#    'maximum_value': 680.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['aerosol particle light hemispheric backscatter coefficient',
#     'aerosol particle light scattering coefficient'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/ES0020U.20230614050000.20230914043809.nephelometer..aerosol.3mo.1h.ES08L_TSI_3563_UGR_NRT.ES08L_scat_coef.lev1.5.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/actris_nrt/ES0020U.20230614050000.20230914043809.nephelometer..aerosol.3mo.1h.ES08L_TSI_3563_UGR_NRT.ES08L_scat_coef.lev1.5.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['in situ particle optical parameter instrument'],
#    'program_affiliation': ['ACTRIS', 'GAW-WDCA', 'NOAA-ESRL'],
#    'variable_statistical_property': ['geometric standard deviation',
#     'linear standard deviation'],
#    'legacy_data': True,
#    'observation_timeliness': 'near real-time',
#    'data_product': 'near-realtime data'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS associated'}},
#  {'md_metadata': {'id': 36,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://prod-actris-md.nilu.no/Providers/14'},
#    'file_identifier': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/IT0004R.20230614050000.20230914043605.nephelometer..pm10.3mo.1h.IT04L_TSI_3563_IPR_dry_NRT.IT04L_scat_coef.lev1.5.nc',
#    'language': 'en',
#    'hierarchy_level': 'nonGeographicDataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2023-09-14T02:36:05.0000000Z',
#    'created': '2023-09-14T11:14:32.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'mf@nilu.no',
#      'position_name': 'Senior scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of nephelometer at Ispra (IT0004R). These measurements are gathered as a part of the following projects ACTRIS_NRT, GAW-WDCA_NRT and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: aerosol_light_backscattering_coefficient in pm10, aerosol_light_backscattering_coefficient in pm10, aerosol_light_backscattering_coefficient in pm10, aerosol_light_scattering_coefficient in pm10, aerosol_light_scattering_coefficient in pm10, aerosol_light_scattering_coefficient in pm10',
#    'title': 'Ground based in situ observations of nephelometer at Ispra (IT0004R)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'JP',
#      'last_name': 'Putaud',
#      'organisation_name': 'EC Joint Research Centre',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'IT'},
#     {'first_name': 'Sebastiao Martins dos',
#      'last_name': 'Santos',
#      'organisation_name': 'EC Joint Research Centre',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'IT'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'it0004r.20230614050000.20230914043605.nephelometer..pm10.3mo.1h.it04l_tsi_3563_ipr_dry_nrt.it04l_scat_coef.lev1.5.nc',
#     'type': 'other PID'},
#    'date': '2023-09-14T02:36:05.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'otherRestrictions',
#    'data_licence': 'https://creativecommons.org/licenses/by/4.0/',
#    'metadata_licence': 'https://creativecommons.org/licenses/by/4.0/'},
#   'md_keywords': {'keywords': ['actris_nrt',
#     'aerosol_light_backscattering_coefficient',
#     'aerosol_light_scattering_coefficient',
#     'gaw-wdca_nrt',
#     'ispra',
#     'it0004r',
#     'pm10']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': 'actris.observational.it.90',
#     'name': 'European Commission Atmospheric Observatory - Main site',
#     'lat': 45.815,
#     'lon': 8.636,
#     'alt': 209.0,
#     'country_code': 'IT',
#     'wmo_region': None,
#     'identifier_type': 'other PID',
#     'uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/127'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.633333,
#    'east_bound_longitude': 8.633333,
#    'south_bound_latitude': 45.8,
#    'north_bound_latitude': 45.8},
#   'ex_temporal_extent': {'time_period_begin': '2023-06-14T03:00:00.0000000Z',
#    'time_period_end': '2023-09-14T02:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 209.0,
#    'maximum_value': 209.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['aerosol particle light hemispheric backscatter coefficient',
#     'aerosol particle light scattering coefficient'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/IT0004R.20230614050000.20230914043605.nephelometer..pm10.3mo.1h.IT04L_TSI_3563_IPR_dry_NRT.IT04L_scat_coef.lev1.5.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/actris_nrt/IT0004R.20230614050000.20230914043605.nephelometer..pm10.3mo.1h.IT04L_TSI_3563_IPR_dry_NRT.IT04L_scat_coef.lev1.5.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['in situ particle optical parameter instrument'],
#    'program_affiliation': ['ACTRIS', 'GAW-WDCA'],
#    'variable_statistical_property': ['geometric standard deviation',
#     'linear standard deviation'],
#    'legacy_data': True,
#    'observation_timeliness': 'near real-time',
#    'data_product': 'near-realtime data'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS associated'}},
#  {'md_metadata': {'id': 45,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://prod-actris-md.nilu.no/Providers/14'},
#    'file_identifier': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/ES0100R.20230614050000.20230914043905.nephelometer..pm1.3mo.1h.ES06L_TSI_3563_ARN_NRT.ES06L_scat_coef.lev1.5.nc',
#    'language': 'en',
#    'hierarchy_level': 'nonGeographicDataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2023-09-14T02:39:05.0000000Z',
#    'created': '2023-09-14T11:14:38.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'mf@nilu.no',
#      'position_name': 'Senior scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of nephelometer at El Arenosillo (ES0100R). These measurements are gathered as a part of the following projects ACTRIS_NRT, GAW-WDCA_NRT, NOAA-ESRL_NRT and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: aerosol_light_backscattering_coefficient in pm1, aerosol_light_backscattering_coefficient in pm1, aerosol_light_backscattering_coefficient in pm1, aerosol_light_scattering_coefficient in pm1, aerosol_light_scattering_coefficient in pm1, aerosol_light_scattering_coefficient in pm1',
#    'title': 'Ground based in situ observations of nephelometer at El Arenosillo (ES0100R)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Maria del Mar Sorribas',
#      'last_name': 'Panero',
#      'organisation_name': 'Not available',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'ES'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'es0100r.20230614050000.20230914043905.nephelometer..pm1.3mo.1h.es06l_tsi_3563_arn_nrt.es06l_scat_coef.lev1.5.nc',
#     'type': 'other PID'},
#    'date': '2023-09-14T02:39:05.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'otherRestrictions',
#    'data_licence': 'https://creativecommons.org/licenses/by/4.0/',
#    'metadata_licence': 'https://creativecommons.org/licenses/by/4.0/'},
#   'md_keywords': {'keywords': ['actris_nrt',
#     'aerosol_light_backscattering_coefficient',
#     'aerosol_light_scattering_coefficient',
#     'arenosillo',
#     'el',
#     'es0100r',
#     'gaw-wdca_nrt',
#     'noaa-esrl_nrt',
#     'pm1']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': 'actris.observational.es.78',
#     'name': 'El Arenosillo - ESAt - Main site',
#     'lat': 37.1,
#     'lon': -6.7,
#     'alt': 40.0,
#     'country_code': 'ES',
#     'wmo_region': None,
#     'identifier_type': 'other PID',
#     'uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/111'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': -6.733333,
#    'east_bound_longitude': -6.733333,
#    'south_bound_latitude': 37.1,
#    'north_bound_latitude': 37.1},
#   'ex_temporal_extent': {'time_period_begin': '2023-06-14T03:00:00.0000000Z',
#    'time_period_end': '2023-09-14T00:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 41.0,
#    'maximum_value': 41.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['aerosol particle light hemispheric backscatter coefficient',
#     'aerosol particle light scattering coefficient'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/ES0100R.20230614050000.20230914043905.nephelometer..pm1.3mo.1h.ES06L_TSI_3563_ARN_NRT.ES06L_scat_coef.lev1.5.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/actris_nrt/ES0100R.20230614050000.20230914043905.nephelometer..pm1.3mo.1h.ES06L_TSI_3563_ARN_NRT.ES06L_scat_coef.lev1.5.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['in situ particle optical parameter instrument'],
#    'program_affiliation': ['ACTRIS', 'GAW-WDCA', 'NOAA-ESRL'],
#    'variable_statistical_property': ['geometric standard deviation',
#     'linear standard deviation'],
#    'legacy_data': True,
#    'observation_timeliness': 'near real-time',
#    'data_product': 'near-realtime data'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS associated'}},
#  {'md_metadata': {'id': 46,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://prod-actris-md.nilu.no/Providers/14'},
#    'file_identifier': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/ES0100R.20230614050000.20230914043630.nephelometer..pm10.3mo.1h.ES06L_TSI_3563_ARN_NRT.ES06L_scat_coef.lev1.5.nc',
#    'language': 'en',
#    'hierarchy_level': 'nonGeographicDataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2023-09-14T02:36:30.0000000Z',
#    'created': '2023-09-14T11:14:39.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'mf@nilu.no',
#      'position_name': 'Senior scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of nephelometer at El Arenosillo (ES0100R). These measurements are gathered as a part of the following projects ACTRIS_NRT, GAW-WDCA_NRT, NOAA-ESRL_NRT and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: aerosol_light_backscattering_coefficient in pm10, aerosol_light_backscattering_coefficient in pm10, aerosol_light_backscattering_coefficient in pm10, aerosol_light_scattering_coefficient in pm10, aerosol_light_scattering_coefficient in pm10, aerosol_light_scattering_coefficient in pm10',
#    'title': 'Ground based in situ observations of nephelometer at El Arenosillo (ES0100R)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Maria del Mar Sorribas',
#      'last_name': 'Panero',
#      'organisation_name': 'Not available',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'ES'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'es0100r.20230614050000.20230914043630.nephelometer..pm10.3mo.1h.es06l_tsi_3563_arn_nrt.es06l_scat_coef.lev1.5.nc',
#     'type': 'other PID'},
#    'date': '2023-09-14T02:36:30.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'otherRestrictions',
#    'data_licence': 'https://creativecommons.org/licenses/by/4.0/',
#    'metadata_licence': 'https://creativecommons.org/licenses/by/4.0/'},
#   'md_keywords': {'keywords': ['actris_nrt',
#     'aerosol_light_backscattering_coefficient',
#     'aerosol_light_scattering_coefficient',
#     'arenosillo',
#     'el',
#     'es0100r',
#     'gaw-wdca_nrt',
#     'noaa-esrl_nrt',
#     'pm10']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': 'actris.observational.es.78',
#     'name': 'El Arenosillo - ESAt - Main site',
#     'lat': 37.1,
#     'lon': -6.7,
#     'alt': 40.0,
#     'country_code': 'ES',
#     'wmo_region': None,
#     'identifier_type': 'other PID',
#     'uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/111'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': -6.733333,
#    'east_bound_longitude': -6.733333,
#    'south_bound_latitude': 37.1,
#    'north_bound_latitude': 37.1},
#   'ex_temporal_extent': {'time_period_begin': '2023-06-14T03:00:00.0000000Z',
#    'time_period_end': '2023-09-14T00:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 41.0,
#    'maximum_value': 41.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['aerosol particle light hemispheric backscatter coefficient',
#     'aerosol particle light scattering coefficient'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/ES0100R.20230614050000.20230914043630.nephelometer..pm10.3mo.1h.ES06L_TSI_3563_ARN_NRT.ES06L_scat_coef.lev1.5.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/actris_nrt/ES0100R.20230614050000.20230914043630.nephelometer..pm10.3mo.1h.ES06L_TSI_3563_ARN_NRT.ES06L_scat_coef.lev1.5.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['in situ particle optical parameter instrument'],
#    'program_affiliation': ['ACTRIS', 'GAW-WDCA', 'NOAA-ESRL'],
#    'variable_statistical_property': ['geometric standard deviation',
#     'linear standard deviation'],
#    'legacy_data': True,
#    'observation_timeliness': 'near real-time',
#    'data_product': 'near-realtime data'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS associated'}},
#  {'md_metadata': {'id': 48,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://prod-actris-md.nilu.no/Providers/14'},
#    'file_identifier': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/DE0043G.20230614050000.20230914051402.smps..pm10.3mo.1h.DE09L_SMPS_MOHP_NRT.DE08L_smps_Adis_OptPar_from_DMPS_0.lev3b.nc',
#    'language': 'en',
#    'hierarchy_level': 'nonGeographicDataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2023-09-14T03:14:02.0000000Z',
#    'created': '2023-09-14T11:14:41.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'mf@nilu.no',
#      'position_name': 'Senior scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of smps at Hohenpeissenberg (DE0043G). These measurements are gathered as a part of the following projects ACTRIS_NRT, EMEP_NRT, GAW-WDCA_NRT and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: aerosol_light_backscattering_coefficient in pm10, aerosol_light_backscattering_coefficient in pm10, aerosol_light_backscattering_coefficient in pm10, aerosol_light_scattering_coefficient in pm10, aerosol_light_scattering_coefficient in pm10, aerosol_light_scattering_coefficient in pm10',
#    'title': 'Ground based in situ observations of smps at Hohenpeissenberg (DE0043G)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Harald',
#      'last_name': 'Flentje',
#      'organisation_name': 'Deutscher Wetterdienst Meteorological Observatory Hohenpeissenberg',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'DE'},
#     {'first_name': 'Bjoern',
#      'last_name': 'Briel',
#      'organisation_name': 'Deutscher Wetterdienst Meteorological Observatory Hohenpeissenberg',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'DE'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'de0043g.20230614050000.20230914051402.smps..pm10.3mo.1h.de09l_smps_mohp_nrt.de08l_smps_adis_optpar_from_dmps_0.lev3b.nc',
#     'type': 'other PID'},
#    'date': '2023-09-14T03:14:02.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'otherRestrictions',
#    'data_licence': 'https://creativecommons.org/licenses/by/4.0/',
#    'metadata_licence': 'https://creativecommons.org/licenses/by/4.0/'},
#   'md_keywords': {'keywords': ['actris_nrt',
#     'aerosol_light_backscattering_coefficient',
#     'aerosol_light_scattering_coefficient',
#     'de0043g',
#     'emep_nrt',
#     'gaw-wdca_nrt',
#     'hohenpeissenberg',
#     'pm10']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': 'actris.observational.de.31',
#     'name': 'Hohenpeissenberg - Main site',
#     'lat': 47.8,
#     'lon': 11.0,
#     'alt': 990.0,
#     'country_code': 'DE',
#     'wmo_region': None,
#     'identifier_type': 'other PID',
#     'uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/47'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 11.009619,
#    'east_bound_longitude': 11.009619,
#    'south_bound_latitude': 47.8014984131,
#    'north_bound_latitude': 47.8014984131},
#   'ex_temporal_extent': {'time_period_begin': '2023-06-14T03:00:00.0000000Z',
#    'time_period_end': '2023-09-14T03:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 975.0,
#    'maximum_value': 975.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['aerosol particle light hemispheric backscatter coefficient',
#     'aerosol particle light scattering coefficient'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/DE0043G.20230614050000.20230914051402.smps..pm10.3mo.1h.DE09L_SMPS_MOHP_NRT.DE08L_smps_Adis_OptPar_from_DMPS_0.lev3b.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/actris_nrt/DE0043G.20230614050000.20230914051402.smps..pm10.3mo.1h.DE09L_SMPS_MOHP_NRT.DE08L_smps_Adis_OptPar_from_DMPS_0.lev3b.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['particle size spectrometer'],
#    'program_affiliation': ['ACTRIS', 'EMEP', 'GAW-WDCA'],
#    'variable_statistical_property': ['geometric standard deviation',
#     'linear standard deviation'],
#    'legacy_data': True,
#    'observation_timeliness': 'near real-time',
#    'data_product': 'near-realtime data'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS associated'}},
#  {'md_metadata': {'id': 49,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://prod-actris-md.nilu.no/Providers/14'},
# ...
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/actris_nrt/FI0038U.20230817100000.20230914051203.cpc...4w.1h.FI03L_CPC_KUM_01_NRT.FI03L_CPC.lev1.5.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['particle counter'],
#    'program_affiliation': ['ACTRIS', 'RI-URBANS'],
#    'variable_statistical_property': ['geometric standard deviation',
#     'linear standard deviation'],
#    'legacy_data': True,
#    'observation_timeliness': 'near real-time',
#    'data_product': 'near-realtime data'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS associated'}},
#  {'md_metadata': {'id': 42,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://prod-actris-md.nilu.no/Providers/14'},
#    'file_identifier': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/FI0038U.20230817100000.20230914051202.dmps...4w.1h.FI03L_UHEL_DMPS_KUM_01_NRT.FI03L_TRY_TDMPS.lev1.5.nc',
#    'language': 'en',
#    'hierarchy_level': 'nonGeographicDataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2023-09-14T03:12:02.0000000Z',
#    'created': '2023-09-14T11:14:36.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'mf@nilu.no',
#      'position_name': 'Senior scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of dmps at Kumpula (FI0038U). These measurements are gathered as a part of the following projects ACTRIS_NRT, RI-URBANS_NRT and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in pm10, particle_number_size_distribution in pm10, particle_number_size_distribution in pm10',
#    'title': 'Ground based in situ observations of dmps at Kumpula (FI0038U)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Markku',
#      'last_name': 'Kulmala',
#      'organisation_name': 'Not available',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'FI'},
#     {'first_name': 'Tuukka',
#      'last_name': 'Petäjä',
#      'organisation_name': 'Not available',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'FI'},
#     {'first_name': 'Leena',
#      'last_name': 'Järvi',
#      'organisation_name': 'Not available',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'FI'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'fi0038u.20230817100000.20230914051202.dmps...4w.1h.fi03l_uhel_dmps_kum_01_nrt.fi03l_try_tdmps.lev1.5.nc',
#     'type': 'other PID'},
#    'date': '2023-09-14T03:12:02.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'otherRestrictions',
#    'data_licence': 'https://creativecommons.org/licenses/by/4.0/',
#    'metadata_licence': 'https://creativecommons.org/licenses/by/4.0/'},
#   'md_keywords': {'keywords': ['actris_nrt',
#     'fi0038u',
#     'kumpula',
#     'particle_number_size_distribution',
#     'pm10',
#     'ri-urbans_nrt']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': 'actris.observational.fi.22',
#     'name': 'SMEAR III - Main site',
#     'lat': 60.2,
#     'lon': 24.967,
#     'alt': 26.0,
#     'country_code': 'FI',
#     'wmo_region': None,
#     'identifier_type': 'other PID',
#     'uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/24'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 24.961207,
#    'east_bound_longitude': 24.961207,
#    'south_bound_latitude': 60.20288,
#    'north_bound_latitude': 60.20288},
#   'ex_temporal_extent': {'time_period_begin': '2023-08-17T08:00:00.0000000Z',
#    'time_period_end': '2023-09-14T03:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 25.0,
#    'maximum_value': 25.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['aerosol particle number size distribution'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/FI0038U.20230817100000.20230914051202.dmps...4w.1h.FI03L_UHEL_DMPS_KUM_01_NRT.FI03L_TRY_TDMPS.lev1.5.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/actris_nrt/FI0038U.20230817100000.20230914051202.dmps...4w.1h.FI03L_UHEL_DMPS_KUM_01_NRT.FI03L_TRY_TDMPS.lev1.5.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['particle size spectrometer'],
#    'program_affiliation': ['ACTRIS', 'RI-URBANS'],
#    'variable_statistical_property': ['geometric standard deviation',
#     'linear standard deviation'],
#    'legacy_data': True,
#    'observation_timeliness': 'near real-time',
#    'data_product': 'near-realtime data'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS associated'}},
#  {'md_metadata': {'id': 50,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://prod-actris-md.nilu.no/Providers/14'},
#    'file_identifier': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/DE0043G.20230614050000.20230914051003.smps...3mo.1h.DE09L_SMPS_MOHP_NRT.DE09L_TROPOS_MOHP__lev0-proc-v0-2-0.lev1.5.nc',
#    'language': 'en',
#    'hierarchy_level': 'nonGeographicDataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2023-09-14T03:10:03.0000000Z',
#    'created': '2023-09-14T11:14:42.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'mf@nilu.no',
#      'position_name': 'Senior scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of smps at Hohenpeissenberg (DE0043G). These measurements are gathered as a part of the following projects ACTRIS_NRT, EMEP_NRT, GAW-WDCA_NRT and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in pm10, particle_number_size_distribution in pm10, particle_number_size_distribution in pm10',
#    'title': 'Ground based in situ observations of smps at Hohenpeissenberg (DE0043G)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Harald',
#      'last_name': 'Flentje',
#      'organisation_name': 'Deutscher Wetterdienst Meteorological Observatory Hohenpeissenberg',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'DE'},
#     {'first_name': 'Bjoern',
#      'last_name': 'Briel',
#      'organisation_name': 'Deutscher Wetterdienst Meteorological Observatory Hohenpeissenberg',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'DE'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'de0043g.20230614050000.20230914051003.smps...3mo.1h.de09l_smps_mohp_nrt.de09l_tropos_mohp__lev0-proc-v0-2-0.lev1.5.nc',
#     'type': 'other PID'},
#    'date': '2023-09-14T03:10:03.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'otherRestrictions',
#    'data_licence': 'https://creativecommons.org/licenses/by/4.0/',
#    'metadata_licence': 'https://creativecommons.org/licenses/by/4.0/'},
#   'md_keywords': {'keywords': ['actris_nrt',
#     'de0043g',
#     'emep_nrt',
#     'gaw-wdca_nrt',
#     'hohenpeissenberg',
#     'particle_number_size_distribution',
#     'pm10']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': 'actris.observational.de.31',
#     'name': 'Hohenpeissenberg - Main site',
#     'lat': 47.8,
#     'lon': 11.0,
#     'alt': 990.0,
#     'country_code': 'DE',
#     'wmo_region': None,
#     'identifier_type': 'other PID',
#     'uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/47'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 11.009619,
#    'east_bound_longitude': 11.009619,
#    'south_bound_latitude': 47.8014984131,
#    'north_bound_latitude': 47.8014984131},
#   'ex_temporal_extent': {'time_period_begin': '2023-06-14T03:00:00.0000000Z',
#    'time_period_end': '2023-09-14T03:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 975.0,
#    'maximum_value': 975.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['aerosol particle number size distribution'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/actris_nrt/DE0043G.20230614050000.20230914051003.smps...3mo.1h.DE09L_SMPS_MOHP_NRT.DE09L_TROPOS_MOHP__lev0-proc-v0-2-0.lev1.5.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/DE0043G.20230614050000.20230914051003.smps...3mo.1h.DE09L_SMPS_MOHP_NRT.DE09L_TROPOS_MOHP__lev0-proc-v0-2-0.lev1.5.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['particle size spectrometer'],
#    'program_affiliation': ['ACTRIS', 'EMEP', 'GAW-WDCA'],
#    'variable_statistical_property': ['geometric standard deviation',
#     'linear standard deviation'],
#    'legacy_data': True,
#    'observation_timeliness': 'near real-time',
#    'data_product': 'near-realtime data'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS associated'}},
#  {'md_metadata': {'id': 43,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://prod-actris-md.nilu.no/Providers/14'},
#    'file_identifier': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/FI0023R.20230829040000.20230914050602.dmps...16d.1h.FI03L_UHEL_DMPS_VAR_02_NRT.FI03L_TRY_TDMPS.lev1.5.nc',
#    'language': 'en',
#    'hierarchy_level': 'nonGeographicDataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2023-09-14T03:06:02.0000000Z',
#    'created': '2023-09-14T11:14:37.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'mf@nilu.no',
#      'position_name': 'Senior scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of dmps at Värriö (FI0023R). These measurements are gathered as a part of the following projects ACTRIS_NRT and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in pm10, particle_number_size_distribution in pm10, particle_number_size_distribution in pm10',
#    'title': 'Ground based in situ observations of dmps at Värriö (FI0023R)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Markku',
#      'last_name': 'Kulmala',
#      'organisation_name': 'Not available',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'FI'},
#     {'first_name': 'Tuukka',
#      'last_name': 'Petäjä',
#      'organisation_name': 'Not available',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'FI'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'fi0023r.20230829040000.20230914050602.dmps...16d.1h.fi03l_uhel_dmps_var_02_nrt.fi03l_try_tdmps.lev1.5.nc',
#     'type': 'other PID'},
#    'date': '2023-09-14T03:06:02.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'otherRestrictions',
#    'data_licence': 'https://creativecommons.org/licenses/by/4.0/',
#    'metadata_licence': 'https://creativecommons.org/licenses/by/4.0/'},
#   'md_keywords': {'keywords': ['actris_nrt',
#     'fi0023r',
#     'particle_number_size_distribution',
#     'pm10',
#     'värriö']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': 'actris.observational.fi.20',
#     'name': 'Varrio - Main site',
#     'lat': 67.767,
#     'lon': 29.583,
#     'alt': 400.0,
#     'country_code': 'FI',
#     'wmo_region': None,
#     'identifier_type': 'other PID',
#     'uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/22'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 29.583333,
#    'east_bound_longitude': 29.583333,
#    'south_bound_latitude': 67.766667,
#    'north_bound_latitude': 67.766667},
#   'ex_temporal_extent': {'time_period_begin': '2023-08-29T02:00:00.0000000Z',
#    'time_period_end': '2023-09-14T03:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 390.0,
#    'maximum_value': 390.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['aerosol particle number size distribution'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/actris_nrt/FI0023R.20230829040000.20230914050602.dmps...16d.1h.FI03L_UHEL_DMPS_VAR_02_NRT.FI03L_TRY_TDMPS.lev1.5.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/actris_nrt/FI0023R.20230829040000.20230914050602.dmps...16d.1h.FI03L_UHEL_DMPS_VAR_02_NRT.FI03L_TRY_TDMPS.lev1.5.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 0.0,
#     'description': 'string'}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['particle size spectrometer'],
#    'program_affiliation': ['ACTRIS'],
#    'variable_statistical_property': ['geometric standard deviation',
#     'linear standard deviation'],
#    'legacy_data': True,
#    'observation_timeliness': 'near real-time',
#    'data_product': 'near-realtime data'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS associated'}}]

# %%
# Each metadata element consists of a dictionary with keys shown in the dropdown menu

dropdown_md_elements = widgets.Dropdown(
    options=list(metadata_archive[0].keys()),
    value=list(metadata_archive[0].keys())[0],
    description='',
    disabled=False,
)

dropdown_md_elements
# Out:
# Dropdown(options=('md_metadata', 'md_identification', 'md_constraints', 'md_keywords', 'md_data_identification…

# %%
# Most of these keys consists of a new dictonary with metadata information. 
# An example is md_metadata, as show below for dmps in Norway. 
md_list = []
for f in metadata_archive:
    md_list.append(f['md_metadata']) 
df_md_metadata = pd.DataFrame.from_records(md_list)

df_md_metadata
# Out:
#     id                                           provider
# 0   38  {'name': 'IN-SITU', 'atom': 'http://prod-actri...  \
# 1   39  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
# 2   35  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
# 3   37  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
# 4   47  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
# 5   36  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
# 6   45  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
# 7   46  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
# 8   48  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
# 9   49  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
# 10  51  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
# 11  44  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
# 12  40  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
# 13  41  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
# 14  42  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
# 15  50  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
# 16  43  {'name': 'IN-SITU', 'atom': 'http://prod-actri...
#
#                                       file_identifier language
# 0   https://thredds.nilu.no/thredds/dodsC/actris_n...       en  \
# 1   https://thredds.nilu.no/thredds/dodsC/actris_n...       en
# 2   https://thredds.nilu.no/thredds/dodsC/actris_n...       en
# 3   https://thredds.nilu.no/thredds/dodsC/actris_n...       en
# 4   https://thredds.nilu.no/thredds/dodsC/actris_n...       en
# 5   https://thredds.nilu.no/thredds/dodsC/actris_n...       en
# 6   https://thredds.nilu.no/thredds/dodsC/actris_n...       en
# 7   https://thredds.nilu.no/thredds/dodsC/actris_n...       en
# 8   https://thredds.nilu.no/thredds/dodsC/actris_n...       en
# 9   https://thredds.nilu.no/thredds/dodsC/actris_n...       en
# 10  https://thredds.nilu.no/thredds/dodsC/actris_n...       en
# 11  https://thredds.nilu.no/thredds/dodsC/actris_n...       en
# 12  https://thredds.nilu.no/thredds/dodsC/actris_n...       en
# 13  https://thredds.nilu.no/thredds/dodsC/actris_n...       en
# 14  https://thredds.nilu.no/thredds/dodsC/actris_n...       en
# 15  https://thredds.nilu.no/thredds/dodsC/actris_n...       en
# 16  https://thredds.nilu.no/thredds/dodsC/actris_n...       en
#
#          hierarchy_level                      online_resource
# 0   nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}  \
# 1   nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
# 2   nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
# 3   nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
# 4   nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
# 5   nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
# 6   nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
# 7   nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
# 8   nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
# 9   nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
# 10  nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
# 11  nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
# 12  nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
# 13  nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
# 14  nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
# 15  nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
# 16  nonGeographicDataset  {'linkage': 'http://ebas.nilu.no/'}
#
#                        datestamp                       created
# 0   2023-08-15T14:40:02.0000000Z  2023-09-14T11:14:33.0000000Z  \
# 1   2023-08-11T07:48:02.0000000Z  2023-09-14T11:14:33.0000000Z
# 2   2023-09-14T03:06:34.0000000Z  2023-09-14T11:14:29.0000000Z
# 3   2023-09-14T03:10:39.0000000Z  2023-09-14T11:14:32.0000000Z
# 4   2023-09-14T02:38:09.0000000Z  2023-09-14T11:14:40.0000000Z
# 5   2023-09-14T02:36:05.0000000Z  2023-09-14T11:14:32.0000000Z
# 6   2023-09-14T02:39:05.0000000Z  2023-09-14T11:14:38.0000000Z
# 7   2023-09-14T02:36:30.0000000Z  2023-09-14T11:14:39.0000000Z
# 8   2023-09-14T03:14:02.0000000Z  2023-09-14T11:14:41.0000000Z
# 9   2023-09-14T03:10:05.0000000Z  2023-09-14T11:14:42.0000000Z
# 10  2023-09-14T03:10:03.0000000Z  2023-09-14T11:14:44.0000000Z
# 11  2023-09-14T03:06:02.0000000Z  2023-09-14T11:14:37.0000000Z
# 12  2023-09-14T03:10:18.0000000Z  2023-09-14T11:14:35.0000000Z
# 13  2023-09-14T03:12:03.0000000Z  2023-09-14T11:14:35.0000000Z
# 14  2023-09-14T03:12:02.0000000Z  2023-09-14T11:14:36.0000000Z
# 15  2023-09-14T03:10:03.0000000Z  2023-09-14T11:14:42.0000000Z
# 16  2023-09-14T03:06:02.0000000Z  2023-09-14T11:14:37.0000000Z
#
#                                               contact
# 0   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 1   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 2   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 3   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 4   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 5   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 6   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 7   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 8   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 9   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 10  [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 11  [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 12  [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 13  [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 14  [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 15  [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 16  [{'first_name': 'Markus', 'last_name': 'Fiebig...

# %%
# Here the column 'contact' includes more information about a contact person for each dataset. 
# As these datasets are all dmps from Norway, the custodian is Markus Fiebig for all. 

contact_list = []
for j in list(df_md_metadata['contact']):
    contact_list.append(j[0])
    
df_contact = pd.DataFrame.from_records(contact_list)

df_contact
# Out:
#    first_name last_name organisation_name    role_code country_code
# 0      Markus    Fiebig              NILU  [custodian]           NO  \
# 1      Markus    Fiebig              NILU  [custodian]           NO
# 2      Markus    Fiebig              NILU  [custodian]           NO
# 3      Markus    Fiebig              NILU  [custodian]           NO
# 4      Markus    Fiebig              NILU  [custodian]           NO
# 5      Markus    Fiebig              NILU  [custodian]           NO
# 6      Markus    Fiebig              NILU  [custodian]           NO
# 7      Markus    Fiebig              NILU  [custodian]           NO
# 8      Markus    Fiebig              NILU  [custodian]           NO
# 9      Markus    Fiebig              NILU  [custodian]           NO
# 10     Markus    Fiebig              NILU  [custodian]           NO
# 11     Markus    Fiebig              NILU  [custodian]           NO
# 12     Markus    Fiebig              NILU  [custodian]           NO
# 13     Markus    Fiebig              NILU  [custodian]           NO
# 14     Markus    Fiebig              NILU  [custodian]           NO
# 15     Markus    Fiebig              NILU  [custodian]           NO
# 16     Markus    Fiebig              NILU  [custodian]           NO
#
#        delivery_point address_city administrative_area  postal_code
# 0   Instituttveien 18      Kjeller               Viken         2007  \
# 1   Instituttveien 18      Kjeller               Viken         2007
# 2   Instituttveien 18      Kjeller               Viken         2007
# 3   Instituttveien 18      Kjeller               Viken         2007
# 4   Instituttveien 18      Kjeller               Viken         2007
# 5   Instituttveien 18      Kjeller               Viken         2007
# 6   Instituttveien 18      Kjeller               Viken         2007
# 7   Instituttveien 18      Kjeller               Viken         2007
# 8   Instituttveien 18      Kjeller               Viken         2007
# 9   Instituttveien 18      Kjeller               Viken         2007
# 10  Instituttveien 18      Kjeller               Viken         2007
# 11  Instituttveien 18      Kjeller               Viken         2007
# 12  Instituttveien 18      Kjeller               Viken         2007
# 13  Instituttveien 18      Kjeller               Viken         2007
# 14  Instituttveien 18      Kjeller               Viken         2007
# 15  Instituttveien 18      Kjeller               Viken         2007
# 16  Instituttveien 18      Kjeller               Viken         2007
#
#          email     position_name
# 0   mf@nilu.no  Senior scientist
# 1   mf@nilu.no  Senior scientist
# 2   mf@nilu.no  Senior scientist
# 3   mf@nilu.no  Senior scientist
# 4   mf@nilu.no  Senior scientist
# 5   mf@nilu.no  Senior scientist
# 6   mf@nilu.no  Senior scientist
# 7   mf@nilu.no  Senior scientist
# 8   mf@nilu.no  Senior scientist
# 9   mf@nilu.no  Senior scientist
# 10  mf@nilu.no  Senior scientist
# 11  mf@nilu.no  Senior scientist
# 12  mf@nilu.no  Senior scientist
# 13  mf@nilu.no  Senior scientist
# 14  mf@nilu.no  Senior scientist
# 15  mf@nilu.no  Senior scientist
# 16  mf@nilu.no  Senior scientist

# %%
# Another example of extracting metadata, here the distribution information of Norwegian dmps datasets.
# The distribution information includes data format, dataset url, protocol, restrictions and more.

files_list = []
for f in metadata_archive:
    url = f['md_distribution_information'][0]
    files_list.append(url)
    
df_distribution_information = pd.DataFrame.from_records(files_list)
df_distribution_information
# Out:
#    data_format version_data_format
# 0       NETCDF                   4  \
# 1       NETCDF                   4
# 2       NETCDF                   4
# 3       NETCDF                   4
# 4       NETCDF                   4
# 5       NETCDF                   4
# 6       NETCDF                   4
# 7       NETCDF                   4
# 8       NETCDF                   4
# 9       NETCDF                   4
# 10      NETCDF                   4
# 11      NETCDF                   4
# 12      NETCDF                   4
# 13      NETCDF                   4
# 14      NETCDF                   4
# 15      NETCDF                   4
# 16      NETCDF                   4
#
#                                           dataset_url protocol   function
# 0   https://thredds.nilu.no/thredds/dodsC/actris_n...  OPeNDAP  streaming  \
# 1   https://thredds.nilu.no/thredds/dodsC/actris_n...  OPeNDAP  streaming
# 2   https://thredds.nilu.no/thredds/dodsC/actris_n...  OPeNDAP  streaming
# 3   https://thredds.nilu.no/thredds/dodsC/actris_n...  OPeNDAP  streaming
# 4   https://thredds.nilu.no/thredds/dodsC/actris_n...  OPeNDAP  streaming
# 5   https://thredds.nilu.no/thredds/dodsC/actris_n...  OPeNDAP  streaming
# 6   https://thredds.nilu.no/thredds/dodsC/actris_n...  OPeNDAP  streaming
# 7   https://thredds.nilu.no/thredds/dodsC/actris_n...  OPeNDAP  streaming
# 8   https://thredds.nilu.no/thredds/dodsC/actris_n...  OPeNDAP  streaming
# 9   https://thredds.nilu.no/thredds/dodsC/actris_n...  OPeNDAP  streaming
# 10  https://thredds.nilu.no/thredds/dodsC/actris_n...  OPeNDAP  streaming
# 11  https://thredds.nilu.no/thredds/fileServer/act...     HTTP   download
# 12  https://thredds.nilu.no/thredds/dodsC/actris_n...  OPeNDAP  streaming
# 13  https://thredds.nilu.no/thredds/dodsC/actris_n...  OPeNDAP  streaming
# 14  https://thredds.nilu.no/thredds/dodsC/actris_n...  OPeNDAP  streaming
# 15  https://thredds.nilu.no/thredds/fileServer/act...     HTTP   download
# 16  https://thredds.nilu.no/thredds/dodsC/actris_n...  OPeNDAP  streaming
#
#        restriction  transfersize description
# 0   {'set': False}           0.0      string
# 1   {'set': False}           0.0      string
# 2   {'set': False}           0.0      string
# 3   {'set': False}           0.0      string
# 4   {'set': False}           0.0      string
# 5   {'set': False}           0.0      string
# 6   {'set': False}           0.0      string
# 7   {'set': False}           0.0      string
# 8   {'set': False}           0.0      string
# 9   {'set': False}           0.0      string
# 10  {'set': False}           0.0      string
# 11  {'set': False}           0.0      string
# 12  {'set': False}           0.0      string
# 13  {'set': False}           0.0      string
# 14  {'set': False}           0.0      string
# 15  {'set': False}           0.0      string
# 16  {'set': False}           0.0      string
