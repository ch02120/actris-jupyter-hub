# %% [markdown]
# <img src='https://www.actris.eu/sites/default/files/inline-images/Actris%20logo.png' width=200 align=right>
#
# # ACTRIS DC
# ## Search with ACTRIS Metadata Rest API

# %% [markdown]
# ## Using ACTRIS metadata catalog REST API
#
# Using the ACTRIS REST API you can access all ACTRIS metadata, stations, instruments, networks etc. It is possible to get the full metadata archive at once, but(!) this can take a bit of time.
#
# ACTRIS Rest API documentation: https://prod-actris-md.nilu.no/index.html
#
# For the latest version including the metadata schema for model data, you would need to look here: https://dev-actris-md.nilu.no/index.html

# %%
# import packages

import pandas as pd
import requests
import json
import ipywidgets as widgets

# %% [markdown]
# ## Browse the metadata archive
#
# This is an example of how to browse and get used to the ACTRIS Rest API metadata catalog and each search element. Some of the most used metadata elements in the the ACTRIS metadata catalog is displayed with all values as dropdown widgets.

# %%
response = requests.get("https://prod-actris-md.nilu.no/Countries") # get all countries in metadata archive
archive = response.json()
df = pd.DataFrame(archive)

# dropdown widget 
dropdown_countries = widgets.Dropdown(
    options=list(df['en_name']),
    value=list(df['en_name'])[0],
    description='Countries:',
    disabled=False,
)

display(dropdown_countries)
# Out:
# Dropdown(description='Countries:', options=('Andorra', 'United Arab Emirates', 'Afghanistan', 'Antigua and Bar…

# %%
response = requests.get("https://prod-actris-md.nilu.no/Instruments")  # get all instruments in metadata archive
archive = response.json()
df = pd.DataFrame(archive)

# dropdown widget 
dropdown_instruments = widgets.Dropdown(
    options=list(df['type']),
    value=list(df['type'])[0],
    description='Instruments:',
    disabled=False,
)

display(dropdown_instruments)
# Out:
# Dropdown(description='Instruments:', options=('ads_tube', 'aerosol_mass_spectrometer', 'aps', 'aws', 'b-attenu…

# %%
response = requests.get("https://prod-actris-md.nilu.no/Networks") # get all networks in metadata archive
archive = response.json()
df = pd.DataFrame(archive)

# dropdown widget
dropdown_networks = widgets.Dropdown(
    options=list(df['name']),
    value=list(df['name'])[0],
    description='Networks:',
    disabled=False,
)

display(dropdown_networks)
# Out:
# Dropdown(description='Networks:', options=('ACTRIS', 'ACTRIS_NRT', 'ACTRIS_preliminary', 'AMAP', 'AMAP_public'…

# %%
response = requests.get("https://prod-actris-md.nilu.no/Stations") # get all stations in metadata archive
archive = response.json()
df = pd.DataFrame(archive)

# dropdown widget
dropdown_Stations = widgets.Dropdown(
    options=list(df['name']),
    value=list(df['name'])[0],
    description='Stations:',
    disabled=False,
)


display(dropdown_Stations)
# Out:
# Dropdown(description='Stations:', options=('Aberystwyth', 'Agia Marina Xyliatou', 'Ahtari', 'Antikythera', 'Al…

# %%
# show all metadata for the station given in the dropdown widget
df[df['name']==dropdown_Stations.value]
# Out:
#    num_id identifier         name     lat    lon   alt country_code wmo_region
# 0     109        ABY  Aberystwyth  51.858 -4.252  15.0           GB     Europe

# %%
# show all metadata for norwegian stations 
stations_norway = df[df['country_code']=='NO'] #select norwegian stations
stations_norway # show archive as table
# Out:
#      num_id identifier               name        lat        lon     alt  \
# 10      111        ARR             Andoya  69.278000  16.008000   380.0
# 19       88        BIR           Birkenes  58.388530   8.252000   219.0
# 70       90        HUD             Hurdal  60.372386  11.078142   300.0
# 83       89        KRV           Kaarvatn  62.783333   8.883333   210.0
# 122     165        NYA         Ny-Ålesund  78.924000  11.870000    25.0
# 163      92        THG        Trollhaugen -72.011700   2.535100  1553.0
# 167      91        TRL              Troll -72.016667   2.533333  1309.0
# 168     213        TUV         Tustervatn  65.833333  13.916667   439.0
# 185      33        ZEP  zeppelin_mountain  78.907150  11.886680     NaN
#
#     country_code  wmo_region
# 10            NO      Europe
# 19            NO      Europe
# 70            NO      Europe
# 83            NO      Europe
# 122           NO      Europe
# 163           NO  Antarctica
# 167           NO  Antarctica
# 168           NO      Europe
# 185           NO      Europe

# %% [markdown]
# ## Accessing metadata
#
# The full ACTRIS metadata catalog can be accessed with https://prod-actris-md.nilu.no/Metadata/, but(!) this can take a bit of time. Therefore its best search using the available search elements such as instrument, country, station, provider etc. Examples of this is shown under.

# %%
# get all metadata for a spesific instrument and country, here a dmps instrument in Norway
response = requests.get("https://prod-actris-md.nilu.no/Metadata/instrument/dmps/country/NO") 
metadata_archive = response.json()

# %%
metadata_archive # show metadata for dmps in Norway
# Out:
# [{'md_metadata': {'id': 511581,
#    'provider_id': 14,
#    'file_identifier': 'NO0042G.20000301000000.20170523103005.dmps.particle_number_size_distribution.aerosol.6y.1h.NO01L_dmps_no42.NO01L_dmps.lev2.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2019-05-14T05:11:37.0000000Z',
#    'created': '2021-02-02T11:38:46.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research (NILU)',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Insituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of particle_number_size_distribution at Zeppelin mountain (Ny-Ålesund) (NO0042G) using dmps. These measurements are gathered as a part of the following projects CREATE, EMEP, NILU, GAW-WDCA and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in aerosol (number_concentration_of_positive_ions_in_dry_aerosol_particles_in_air)',
#    'title': 'Ground based in situ observations of particle_number_size_distribution at Zeppelin mountain (Ny-Ålesund) (NO0042G) using dmps',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Johan',
#      'last_name': 'Strom',
#      'organisation_name': 'Institute of Applied Environmental Research (Air Pollution Labor',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'AT',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': None,
#      'position_name': None}],
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'identifier': {'id': 'N/A', 'type': 'DOI'},
#    'date': '2017-05-23T08:30:05.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'CREATE: Fair use data policy (see also EMEP and WMO-GAW), EMEP: Public open access. We encourage contacting data originators if substatial use of individual time series is planned (fair use data policy)., NILU: Public open access. We encourage contacting data originators if substatial use of individual time series is planned (fair use data policy)., GAW-WDCA:'},
#   'md_keywords': {'keywords': ['aerosol',
#     'create',
#     'emep',
#     'gaw-wdca',
#     'nilu',
#     'no0042g',
#     'number_concentration_of_positive_ions_in_dry_aerosol_particles_in_air',
#     'particle_number_size_distribution',
#     'status_flag',
#     'time',
#     'zeppelin mountain (ny-ålesund)']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'station': {'identifier': 'ZEP',
#     'name': 'zeppelin_mountain',
#     'lat': 78.90715,
#     'lon': 11.88668,
#     'alt': None,
#     'country_code': 'NO',
#     'wmo_region': 'Europe'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 11.88668,
#    'east_bound_longitude': 11.88668,
#    'south_bound_latitude': 78.90715,
#    'north_bound_latitude': 78.90715},
#   'ex_temporal_extent': {'time_period_begin': '2000-03-01T00:30:00.0000000Z',
#    'time_period_end': '2005-12-31T23:30:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 474.0,
#    'maximum_value': 474.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['particle.number.size.distribution'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'http://thredds.nilu.no/thredds/dodsC/ebas/NO0042G.20000301000000.20170523103005.dmps.particle_number_size_distribution.aerosol.6y.1h.NO01L_dmps_no42.NO01L_dmps.lev2.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'download',
#     'restriction': {'set': False, 'description_url': None},
#     'transfersize': None,
#     'description': 'Direct download of data file'}],
#   'md_actris_specific': {'platform_type': 'surface_station',
#    'product_type': 'observation',
#    'matrix': 'Particle',
#    'sub_matrix': 'Unknown',
#    'instrument_type': ['dmps'],
#    'program_affiliation': ['CREATE', 'EMEP', 'GAW-WDCA', 'NILU'],
#    'legacy_data': True,
#    'data_level': 2,
#    'data_product': 'quality assured data'},
#   'dq_data_quality_information': {'level': 'dataset',
#    'statement': 'Data collected according to instrument specific standard operating procedures, checked on import into data base.',
#    'description': None}},
#  {'md_metadata': {'id': 511703,
#    'provider_id': 14,
#    'file_identifier': 'NO0002R.20151217090000.20170504082503.dmps.particle_number_size_distribution.pm10.72w.1h.NO01L_NILU_DMPSmodel2_BIR_NRT.NO01L_dmps_DMPS_BIR05..nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2019-05-14T04:53:52.0000000Z',
#    'created': '2021-02-12T15:25:15.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research (NILU)',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Insituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of particle_number_size_distribution at Birkenes II (NO0002R) using dmps. These measurements are gathered as a part of the following projects GAW-WDCA_NRT, ACTRIS_NRT, NILU_NRT and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in pm10',
#    'title': 'Ground based in situ observations of particle_number_size_distribution at Birkenes II (NO0002R) using dmps',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Chris',
#      'last_name': 'Lunder',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': 'crl@nilu.no',
#      'position_name': None},
#     {'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': 'Markus.Fiebig@nilu.no',
#      'position_name': None}],
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'identifier': {'id': 'N/A', 'type': 'DOI'},
#    'date': '2017-05-04T06:25:03.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'GAW-WDCA_NRT: , ACTRIS_NRT: http://actris.nilu.no/Content/Documents/DataPolicy.pdf, NILU_NRT: Data can not be published without specific agreement from NILU.'},
#   'md_keywords': {'keywords': ['actris_nrt',
#     'air_pressure',
#     'air_temperature',
#     'birkenes ii',
#     'gaw-wdca_nrt',
#     'nilu_nrt',
#     'no0002r',
#     'particle_number_size_distribution',
#     'pm10',
#     'status_flag',
#     'time']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'station': {'identifier': 'BIR',
#     'name': 'Birkenes',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.252,
#    'east_bound_longitude': 8.252,
#    'south_bound_latitude': 58.38853,
#    'north_bound_latitude': 58.38853},
#   'ex_temporal_extent': {'time_period_begin': '2015-12-17T09:30:00.0000000Z',
#    'time_period_end': '2017-05-04T07:30:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 219.0,
#    'maximum_value': 219.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['particle.number.size.distribution'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'http://thredds.nilu.no/thredds/dodsC/ebas/NO0002R.20151217090000.20170504082503.dmps.particle_number_size_distribution.pm10.72w.1h.NO01L_NILU_DMPSmodel2_BIR_NRT.NO01L_dmps_DMPS_BIR05..nc',
#     'protocol': 'OPeNDAP',
#     'function': 'download',
#     'restriction': {'set': False, 'description_url': None},
#     'transfersize': None,
#     'description': 'Direct download of data file'}],
#   'md_actris_specific': {'platform_type': 'surface_station',
#    'product_type': 'observation',
#    'matrix': 'Particle',
#    'sub_matrix': 'Unknown',
#    'instrument_type': ['dmps'],
#    'program_affiliation': ['ACTRIS_NRT', 'GAW-WDCA_NRT', 'NILU_NRT'],
#    'legacy_data': True,
#    'data_level': 2,
#    'data_product': 'quality assured data'},
#   'dq_data_quality_information': {'level': 'dataset',
#    'statement': 'Data collected according to instrument specific standard operating procedures, checked on import into data base.',
#    'description': None}},
#  {'md_metadata': {'id': 511639,
#    'provider_id': 14,
#    'file_identifier': 'NO0059G.20160125170000.20170503133502.dmps.particle_number_size_distribution.pm10.15mo.1h.NO01L_DMPS_TRL2_NRT.NO01L_dmps_DMPS_TRL02..nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2019-05-14T05:26:15.0000000Z',
#    'created': '2021-02-11T14:43:10.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research (NILU)',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Insituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of particle_number_size_distribution at Trollhaugen (NO0059G) using dmps. These measurements are gathered as a part of the following projects GAW-WDCA_NRT, ACTRIS_NRT, NILU_NRT and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in pm10',
#    'title': 'Ground based in situ observations of particle_number_size_distribution at Trollhaugen (NO0059G) using dmps',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Chris',
#      'last_name': 'Lunder',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': 'crl@nilu.no',
#      'position_name': None},
#     {'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': 'Markus.Fiebig@nilu.no',
#      'position_name': None}],
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'identifier': {'id': 'N/A', 'type': 'DOI'},
#    'date': '2017-05-03T11:35:02.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'GAW-WDCA_NRT: , ACTRIS_NRT: http://actris.nilu.no/Content/Documents/DataPolicy.pdf, NILU_NRT: Data can not be published without specific agreement from NILU.'},
#   'md_keywords': {'keywords': ['actris_nrt',
#     'air_pressure',
#     'air_temperature',
#     'gaw-wdca_nrt',
#     'nilu_nrt',
#     'no0059g',
#     'particle_number_size_distribution',
#     'pm10',
#     'status_flag',
#     'time',
#     'trollhaugen']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'station': {'identifier': 'THG',
#     'name': 'Trollhaugen',
#     'lat': -72.0117,
#     'lon': 2.5351,
#     'alt': 1553.0,
#     'country_code': 'NO',
#     'wmo_region': 'Antarctica'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 2.5351,
#    'east_bound_longitude': 2.5351,
#    'south_bound_latitude': -72.0117,
#    'north_bound_latitude': -72.0117},
#   'ex_temporal_extent': {'time_period_begin': '2016-01-25T17:30:00.0000000Z',
#    'time_period_end': '2017-05-05T09:30:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 1553.0,
#    'maximum_value': 1553.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['particle.number.size.distribution'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'http://thredds.nilu.no/thredds/dodsC/ebas/NO0059G.20160125170000.20170503133502.dmps.particle_number_size_distribution.pm10.15mo.1h.NO01L_DMPS_TRL2_NRT.NO01L_dmps_DMPS_TRL02..nc',
#     'protocol': 'OPeNDAP',
#     'function': 'download',
#     'restriction': {'set': False, 'description_url': None},
#     'transfersize': None,
#     'description': 'Direct download of data file'}],
#   'md_actris_specific': {'platform_type': 'surface_station',
#    'product_type': 'observation',
#    'matrix': 'Particle',
#    'sub_matrix': 'Unknown',
#    'instrument_type': ['dmps'],
#    'program_affiliation': ['ACTRIS_NRT', 'GAW-WDCA_NRT', 'NILU_NRT'],
#    'legacy_data': True,
#    'data_level': 2,
#    'data_product': 'quality assured data'},
#   'dq_data_quality_information': {'level': 'dataset',
#    'statement': 'Data collected according to instrument specific standard operating procedures, checked on import into data base.',
#    'description': None}},
#  {'md_metadata': {'id': 511644,
#    'provider_id': 14,
#    'file_identifier': 'NO0059G.20140129180000.20181205100800.dmps.particle_number_size_distribution.pm10.23mo.1h.NO01L_MISU_DMPSmodel1_TRL.NO01L_dmps_DMPS_Troll1.lev2.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2019-05-14T05:26:21.0000000Z',
#    'created': '2021-02-11T14:43:35.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research (NILU)',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Insituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of particle_number_size_distribution at Trollhaugen (NO0059G) using dmps. These measurements are gathered as a part of the following projects ACTRIS, GAW-WDCA, NILU and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in pm10',
#    'title': 'Ground based in situ observations of particle_number_size_distribution at Trollhaugen (NO0059G) using dmps',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': 'Markus.Fiebig@nilu.no',
#      'position_name': None},
#     {'first_name': 'Chris',
#      'last_name': 'Lunder',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': 'crl@nilu.no',
#      'position_name': None}],
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'identifier': {'id': 'N/A', 'type': 'DOI'},
#    'date': '2018-12-05T09:08:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'ACTRIS: http://actris.nilu.no/Content/Documents/DataPolicy.pdf, GAW-WDCA: , NILU: Public open access. We encourage contacting data originators if substatial use of individual time series is planned (fair use data policy).'},
#   'md_keywords': {'keywords': ['actris',
#     'gaw-wdca',
#     'nilu',
#     'no0059g',
#     'particle_number_size_distribution',
#     'pm10',
#     'relative_humidity',
#     'status_flag',
#     'time',
#     'trollhaugen']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'station': {'identifier': 'THG',
#     'name': 'Trollhaugen',
#     'lat': -72.0117,
#     'lon': 2.5351,
#     'alt': 1553.0,
#     'country_code': 'NO',
#     'wmo_region': 'Antarctica'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 2.533333,
#    'east_bound_longitude': 2.533333,
#    'south_bound_latitude': 72.016667,
#    'north_bound_latitude': 72.016667},
#   'ex_temporal_extent': {'time_period_begin': '2014-01-29T18:30:00.0000000Z',
#    'time_period_end': '2015-12-31T23:30:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 1309.0,
#    'maximum_value': 1309.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['particle.number.size.distribution'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'http://thredds.nilu.no/thredds/dodsC/ebas/NO0059G.20140129180000.20181205100800.dmps.particle_number_size_distribution.pm10.23mo.1h.NO01L_MISU_DMPSmodel1_TRL.NO01L_dmps_DMPS_Troll1.lev2.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'download',
#     'restriction': {'set': False, 'description_url': None},
#     'transfersize': None,
#     'description': 'Direct download of data file'}],
#   'md_actris_specific': {'platform_type': 'surface_station',
#    'product_type': 'observation',
#    'matrix': 'Particle',
#    'sub_matrix': 'Unknown',
#    'instrument_type': ['dmps'],
#    'program_affiliation': ['ACTRIS', 'GAW-WDCA', 'NILU'],
#    'legacy_data': True,
#    'data_level': 2,
#    'data_product': 'quality assured data'},
#   'dq_data_quality_information': {'level': 'dataset',
#    'statement': 'Data collected according to instrument specific standard operating procedures, checked on import into data base.',
#    'description': None}},
#  {'md_metadata': {'id': 511648,
#    'provider_id': 14,
#    'file_identifier': 'NO0058G.20070218000000.20181205100800.dmps.particle_number_size_distribution.aerosol.3y.1h.NO01L_DMPS_Troll1.NO01L_dmps_DMPS_Troll1.lev2.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2019-05-14T05:22:20.0000000Z',
#    'created': '2021-02-11T14:44:27.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research (NILU)',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Insituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of particle_number_size_distribution at Troll (NO0058G) using dmps. These measurements are gathered as a part of the following projects GAW-WDCA, NILU and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in aerosol (number_concentration_of_positive_ions_in_dry_aerosol_particles_in_air)',
#    'title': 'Ground based in situ observations of particle_number_size_distribution at Troll (NO0058G) using dmps',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Chris',
#      'last_name': 'Lunder',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': 'crl@nilu.no',
#      'position_name': None}],
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'identifier': {'id': 'N/A', 'type': 'DOI'},
#    'date': '2018-12-05T09:08:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'GAW-WDCA: , NILU: Public open access. We encourage contacting data originators if substatial use of individual time series is planned (fair use data policy).'},
#   'md_keywords': {'keywords': ['aerosol',
#     'air_pressure',
#     'air_temperature',
#     'gaw-wdca',
#     'nilu',
#     'no0058g',
#     'number_concentration_of_positive_ions_in_dry_aerosol_particles_in_air',
#     'particle_number_size_distribution',
#     'status_flag',
#     'time',
#     'troll']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'station': {'identifier': 'TRL',
#     'name': 'Troll',
#     'lat': -72.016667,
#     'lon': 2.533333,
#     'alt': 1309.0,
#     'country_code': 'NO',
#     'wmo_region': 'Antarctica'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 2.533333,
#    'east_bound_longitude': 2.533333,
#    'south_bound_latitude': -72.016667,
#    'north_bound_latitude': -72.016667},
#   'ex_temporal_extent': {'time_period_begin': '2007-02-18T00:30:00.0000000Z',
#    'time_period_end': '2009-12-31T23:30:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 1309.0,
#    'maximum_value': 1309.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['particle.number.size.distribution'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'http://thredds.nilu.no/thredds/dodsC/ebas/NO0058G.20070218000000.20181205100800.dmps.particle_number_size_distribution.aerosol.3y.1h.NO01L_DMPS_Troll1.NO01L_dmps_DMPS_Troll1.lev2.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'download',
#     'restriction': {'set': False, 'description_url': None},
#     'transfersize': None,
#     'description': 'Direct download of data file'}],
#   'md_actris_specific': {'platform_type': 'surface_station',
#    'product_type': 'observation',
#    'matrix': 'Particle',
#    'sub_matrix': 'Unknown',
#    'instrument_type': ['dmps'],
#    'program_affiliation': ['GAW-WDCA', 'NILU'],
#    'legacy_data': True,
#    'data_level': 2,
#    'data_product': 'quality assured data'},
#   'dq_data_quality_information': {'level': 'dataset',
#    'statement': 'Data collected according to instrument specific standard operating procedures, checked on import into data base.',
#    'description': None}},
#  {'md_metadata': {'id': 511651,
#    'provider_id': 14,
#    'file_identifier': 'NO0042G.20160506060000.20170505102504.dmps.particle_number_size_distribution.pm10.1y.1h.NO01L_DMPS_ZEP1_NRT.NO01L_dmps_DMPS_ZEP01..nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2019-05-14T05:11:08.0000000Z',
#    'created': '2021-02-11T14:52:38.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research (NILU)',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Insituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of particle_number_size_distribution at Zeppelin mountain (Ny-Ålesund) (NO0042G) using dmps. These measurements are gathered as a part of the following projects GAW-WDCA_NRT, ACTRIS_NRT, NILU_NRT, EUSAAR_NRT and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in pm10',
#    'title': 'Ground based in situ observations of particle_number_size_distribution at Zeppelin mountain (Ny-Ålesund) (NO0042G) using dmps',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Chris',
#      'last_name': 'Lunder',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': 'crl@nilu.no',
#      'position_name': None},
#     {'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': 'Markus.Fiebig@nilu.no',
#      'position_name': None}],
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'identifier': {'id': 'N/A', 'type': 'DOI'},
#    'date': '2017-05-05T08:25:04.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'GAW-WDCA_NRT: , ACTRIS_NRT: http://actris.nilu.no/Content/Documents/DataPolicy.pdf, NILU_NRT: Data can not be published without specific agreement from NILU., EUSAAR_NRT:'},
#   'md_keywords': {'keywords': ['actris_nrt',
#     'air_pressure',
#     'air_temperature',
#     'eusaar_nrt',
#     'gaw-wdca_nrt',
#     'nilu_nrt',
#     'no0042g',
#     'particle_number_size_distribution',
#     'pm10',
#     'status_flag',
#     'time',
#     'zeppelin mountain (ny-ålesund)']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'station': {'identifier': 'ZEP',
#     'name': 'zeppelin_mountain',
#     'lat': 78.90715,
#     'lon': 11.88668,
#     'alt': None,
#     'country_code': 'NO',
#     'wmo_region': 'Europe'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 11.88668,
#    'east_bound_longitude': 11.88668,
#    'south_bound_latitude': 78.90715,
#    'north_bound_latitude': 78.90715},
#   'ex_temporal_extent': {'time_period_begin': '2016-05-06T06:30:00.0000000Z',
#    'time_period_end': '2017-05-05T09:30:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 474.0,
#    'maximum_value': 474.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['particle.number.size.distribution'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'http://thredds.nilu.no/thredds/dodsC/ebas/NO0042G.20160506060000.20170505102504.dmps.particle_number_size_distribution.pm10.1y.1h.NO01L_DMPS_ZEP1_NRT.NO01L_dmps_DMPS_ZEP01..nc',
#     'protocol': 'OPeNDAP',
#     'function': 'download',
#     'restriction': {'set': False, 'description_url': None},
#     'transfersize': None,
#     'description': 'Direct download of data file'}],
#   'md_actris_specific': {'platform_type': 'surface_station',
#    'product_type': 'observation',
#    'matrix': 'Particle',
#    'sub_matrix': 'Unknown',
#    'instrument_type': ['dmps'],
#    'program_affiliation': ['ACTRIS_NRT',
#     'EUSAAR_NRT',
#     'GAW-WDCA_NRT',
#     'NILU_NRT'],
#    'legacy_data': True,
#    'data_level': 2,
#    'data_product': 'quality assured data'},
#   'dq_data_quality_information': {'level': 'dataset',
#    'statement': 'Data collected according to instrument specific standard operating procedures, checked on import into data base.',
#    'description': None}},
#  {'md_metadata': {'id': 1005679,
#    'provider_id': 14,
#    'file_identifier': 'NO0002R.20090710120000.20211213092553.dmps...30mo.1h.NO01L_NILU_DMPSmodel2_BIR.NO01L_dmps_DMPS_BIR08__lev0-proc-v0-2-0.lev2.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2021-12-13T08:25:53.0000000Z',
#    'created': '2021-12-14T08:00:37.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research (NILU)',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Insituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of dmps at Birkenes II (NO0002R). These measurements are gathered as a part of the following projects CREATE, EMEP, EUSAAR, GAW-WDCA, NILU and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in pm10, particle_number_size_distribution in pm10, particle_number_size_distribution in pm10',
#    'title': 'Ground based in situ observations of dmps at Birkenes II (NO0002R)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Chris',
#      'last_name': 'Lunder',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': None,
#      'position_name': None},
#     {'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': None,
#      'position_name': None}],
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'identifier': {'id': 'N/A', 'type': 'DOI'},
#    'date': '2021-12-13T08:25:53.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'CREATE: Fair use data policy (see also EMEP and WMO-GAW), EMEP: Public open access. We encourage contacting data originators if substatial use of individual time series is planned (fair use data policy)., EUSAAR: http://www.eusaar.net/files/data/data_protocol.cfm, GAW-WDCA: , NILU: Public open access. We encourage contacting data originators if substatial use of individual time series is planned (fair use data policy).'},
#   'md_keywords': {'keywords': ['birkenes ii',
#     'create',
#     'emep',
#     'eusaar',
#     'gaw-wdca',
#     'nilu',
#     'no0002r',
#     'particle_number_size_distribution',
#     'pm10']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'station': {'identifier': 'BIR',
#     'name': 'Birkenes',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.25,
#    'east_bound_longitude': 8.25,
#    'south_bound_latitude': 58.38,
#    'north_bound_latitude': 58.38},
#   'ex_temporal_extent': {'time_period_begin': '2009-07-10T10:00:00.0000000Z',
#    'time_period_end': '2011-12-31T23:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 220.0,
#    'maximum_value': 220.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['particle.number.size.distribution'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas/NO0002R.20090710120000.20211213092553.dmps...30mo.1h.NO01L_NILU_DMPSmodel2_BIR.NO01L_dmps_DMPS_BIR08__lev0-proc-v0-2-0.lev2.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False, 'description_url': None},
#     'transfersize': None,
#     'description': 'Direct download of data file'}],
#   'md_actris_specific': {'platform_type': 'surface_station',
#    'product_type': 'observation',
#    'matrix': 'Particle',
#    'sub_matrix': 'Unknown',
#    'instrument_type': ['dmps'],
#    'program_affiliation': ['CREATE', 'EMEP', 'EUSAAR', 'GAW-WDCA', 'NILU'],
#    'legacy_data': True,
#    'data_level': 2,
#    'data_product': 'quality assured data'},
#   'dq_data_quality_information': {'level': 'dataset',
#    'statement': 'Data collected according to instrument specific standard operating procedures, checked on import into data base.',
#    'description': None}},
#  {'md_metadata': {'id': 1005684,
#    'provider_id': 14,
#    'file_identifier': 'NO0002R.20131003090000.20210826200223.dmps...74d.1h.NO01L_NILU_DMPSmodel2_BIR.NO01L_dmps_DMPS_BIR10__lev0-proc-v0-2-0.lev2.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2021-08-26T18:02:23.0000000Z',
#    'created': '2021-12-14T08:04:47.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research (NILU)',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Insituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of dmps at Birkenes II (NO0002R). These measurements are gathered as a part of the following projects CREATE, EMEP, EUSAAR, GAW-WDCA, NILU and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in pm10, particle_number_size_distribution in pm10, particle_number_size_distribution in pm10',
#    'title': 'Ground based in situ observations of dmps at Birkenes II (NO0002R)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Chris',
#      'last_name': 'Lunder',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': None,
#      'position_name': None},
#     {'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': None,
#      'position_name': None}],
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'identifier': {'id': 'N/A', 'type': 'DOI'},
#    'date': '2021-08-26T18:02:23.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'CREATE: Fair use data policy (see also EMEP and WMO-GAW), EMEP: Public open access. We encourage contacting data originators if substatial use of individual time series is planned (fair use data policy)., EUSAAR: http://www.eusaar.net/files/data/data_protocol.cfm, GAW-WDCA: , NILU: Public open access. We encourage contacting data originators if substatial use of individual time series is planned (fair use data policy).'},
#   'md_keywords': {'keywords': ['birkenes ii',
#     'create',
#     'emep',
#     'eusaar',
#     'gaw-wdca',
#     'nilu',
#     'no0002r',
#     'particle_number_size_distribution',
#     'pm10']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'station': {'identifier': 'BIR',
#     'name': 'Birkenes',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.25,
#    'east_bound_longitude': 8.25,
#    'south_bound_latitude': 58.38,
#    'north_bound_latitude': 58.38},
#   'ex_temporal_extent': {'time_period_begin': '2013-10-03T07:00:00.0000000Z',
#    'time_period_end': '2013-12-16T13:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 220.0,
#    'maximum_value': 220.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['particle.number.size.distribution'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas/NO0002R.20131003090000.20210826200223.dmps...74d.1h.NO01L_NILU_DMPSmodel2_BIR.NO01L_dmps_DMPS_BIR10__lev0-proc-v0-2-0.lev2.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False, 'description_url': None},
#     'transfersize': None,
#     'description': 'Direct download of data file'}],
#   'md_actris_specific': {'platform_type': 'surface_station',
#    'product_type': 'observation',
#    'matrix': 'Particle',
#    'sub_matrix': 'Unknown',
#    'instrument_type': ['dmps'],
#    'program_affiliation': ['CREATE', 'EMEP', 'EUSAAR', 'GAW-WDCA', 'NILU'],
#    'legacy_data': True,
#    'data_level': 2,
#    'data_product': 'quality assured data'},
#   'dq_data_quality_information': {'level': 'dataset',
#    'statement': 'Data collected according to instrument specific standard operating procedures, checked on import into data base.',
#    'description': None}},
#  {'md_metadata': {'id': 1005685,
#    'provider_id': 14,
#    'file_identifier': 'NO0002R.20131216200000.20211213115154.dmps...15d.1h.NO01L_NILU_DMPSmodel2_BIR.NO01L_dmps_DMPS_BIR11__lev0-proc-v0-2-0.lev2.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2021-12-13T10:51:54.0000000Z',
#    'created': '2021-12-14T08:04:47.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research (NILU)',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Insituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of dmps at Birkenes II (NO0002R). These measurements are gathered as a part of the following projects CREATE, EMEP, EUSAAR, GAW-WDCA, NILU and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in pm10, particle_number_size_distribution in pm10, particle_number_size_distribution in pm10',
#    'title': 'Ground based in situ observations of dmps at Birkenes II (NO0002R)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Chris',
#      'last_name': 'Lunder',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': None,
#      'position_name': None},
#     {'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': None,
#      'position_name': None}],
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'identifier': {'id': 'N/A', 'type': 'DOI'},
#    'date': '2021-12-13T10:51:54.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'CREATE: Fair use data policy (see also EMEP and WMO-GAW), EMEP: Public open access. We encourage contacting data originators if substatial use of individual time series is planned (fair use data policy)., EUSAAR: http://www.eusaar.net/files/data/data_protocol.cfm, GAW-WDCA: , NILU: Public open access. We encourage contacting data originators if substatial use of individual time series is planned (fair use data policy).'},
#   'md_keywords': {'keywords': ['birkenes ii',
#     'create',
#     'emep',
#     'eusaar',
#     'gaw-wdca',
#     'nilu',
#     'no0002r',
#     'particle_number_size_distribution',
#     'pm10']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'station': {'identifier': 'BIR',
#     'name': 'Birkenes',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.25,
#    'east_bound_longitude': 8.25,
#    'south_bound_latitude': 58.38,
#    'north_bound_latitude': 58.38},
#   'ex_temporal_extent': {'time_period_begin': '2013-12-16T19:00:00.0000000Z',
#    'time_period_end': '2013-12-31T23:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 220.0,
#    'maximum_value': 220.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['particle.number.size.distribution'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas/NO0002R.20131216200000.20211213115154.dmps...15d.1h.NO01L_NILU_DMPSmodel2_BIR.NO01L_dmps_DMPS_BIR11__lev0-proc-v0-2-0.lev2.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False, 'description_url': None},
#     'transfersize': None,
#     'description': 'Direct download of data file'}],
#   'md_actris_specific': {'platform_type': 'surface_station',
#    'product_type': 'observation',
#    'matrix': 'Particle',
#    'sub_matrix': 'Unknown',
#    'instrument_type': ['dmps'],
#    'program_affiliation': ['CREATE', 'EMEP', 'EUSAAR', 'GAW-WDCA', 'NILU'],
#    'legacy_data': True,
#    'data_level': 2,
#    'data_product': 'quality assured data'},
#   'dq_data_quality_information': {'level': 'dataset',
#    'statement': 'Data collected according to instrument specific standard operating procedures, checked on import into data base.',
#    'description': None}},
#  {'md_metadata': {'id': 1012230,
#    'provider_id': 14,
#    'file_identifier': 'NO0002R.20120101000000.20211220114453.dmps...20mo.1h.NO01L_NILU_DMPSmodel2_BIR.NO01L_dmps_DMPS_BIR09__lev0-proc-v0-2-0.lev2.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2021-12-20T10:44:53.0000000Z',
#    'created': '2021-12-21T08:05:33.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research (NILU)',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Insituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of dmps at Birkenes II (NO0002R). These measurements are gathered as a part of the following projects CREATE, EMEP, EUSAAR, GAW-WDCA, NILU and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in pm10, particle_number_size_distribution in pm10, particle_number_size_distribution in pm10',
#    'title': 'Ground based in situ observations of dmps at Birkenes II (NO0002R)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Chris',
#      'last_name': 'Lunder',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': None,
#      'position_name': None},
#     {'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': None,
#      'position_name': None}],
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'identifier': {'id': 'N/A', 'type': 'DOI'},
#    'date': '2021-12-20T10:44:53.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'CREATE: Fair use data policy (see also EMEP and WMO-GAW), EMEP: Public open access. We encourage contacting data originators if substatial use of individual time series is planned (fair use data policy)., EUSAAR: http://www.eusaar.net/files/data/data_protocol.cfm, GAW-WDCA: , NILU: Public open access. We encourage contacting data originators if substatial use of individual time series is planned (fair use data policy).'},
#   'md_keywords': {'keywords': ['birkenes ii',
#     'create',
#     'emep',
#     'eusaar',
#     'gaw-wdca',
#     'nilu',
#     'no0002r',
#     'particle_number_size_distribution',
#     'pm10']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'station': {'identifier': 'BIR',
#     'name': 'Birkenes',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.25,
#    'east_bound_longitude': 8.25,
#    'south_bound_latitude': 58.38,
#    'north_bound_latitude': 58.38},
#   'ex_temporal_extent': {'time_period_begin': '2011-12-31T23:00:00.0000000Z',
#    'time_period_end': '2013-08-26T10:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 220.0,
#    'maximum_value': 220.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['particle.number.size.distribution'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas/NO0002R.20120101000000.20211220114453.dmps...20mo.1h.NO01L_NILU_DMPSmodel2_BIR.NO01L_dmps_DMPS_BIR09__lev0-proc-v0-2-0.lev2.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False, 'description_url': None},
#     'transfersize': None,
#     'description': 'Direct download of data file'}],
#   'md_actris_specific': {'platform_type': 'surface_station',
#    'product_type': 'observation',
#    'matrix': 'Particle',
#    'sub_matrix': 'Unknown',
#    'instrument_type': ['dmps'],
#    'program_affiliation': ['CREATE', 'EMEP', 'EUSAAR', 'GAW-WDCA', 'NILU'],
#    'legacy_data': True,
#    'data_level': 2,
#    'data_product': 'quality assured data'},
#   'dq_data_quality_information': {'level': 'dataset',
#    'statement': 'Data collected according to instrument specific standard operating procedures, checked on import into data base.',
#    'description': None}},
#  {'md_metadata': {'id': 789516,
#    'provider_id': 14,
#    'file_identifier': 'NO0042G.20100101000000.20210621122141.dmps...11y.1h.SE02L_TINTIN.SE02L_DMPS_EUSAAR.lev2.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2021-06-21T10:21:41.0000000Z',
#    'created': '2021-06-28T14:07:29.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'Norwegian Institute for Air Research (NILU)',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Insituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Ground based in situ observations of dmps at Zeppelin mountain (Ny-Ålesund) (NO0042G). These measurements are gathered as a part of the following projects ACTRIS, GAW-WDCA and they are stored in the EBAS database (http://ebas.nilu.no/). Parameters measured are: particle_number_size_distribution in pm10, particle_number_size_distribution in pm10, particle_number_size_distribution in pm10',
#    'title': 'Ground based in situ observations of dmps at Zeppelin mountain (Ny-Ålesund) (NO0042G)',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Peter',
#      'last_name': 'Tunved',
#      'organisation_name': 'Organisation name not available',
#      'role_code': ['principalInvestigator'],
#      'country_code': 'NO',
#      'delivery_point': None,
#      'address_city': None,
#      'administrative_area': None,
#      'postal_code': None,
#      'email': None,
#      'position_name': None}],
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'identifier': {'id': 'N/A', 'type': 'DOI'},
#    'date': '2021-06-21T10:21:41.0000000Z'},
#   'md_constraints': {'access_constraints': 'otherRestrictions',
#    'use_constraints': 'otherRestrictions',
#    'other_constraints': 'ACTRIS: http://actris.nilu.no/Content/Documents/DataPolicy.pdf, GAW-WDCA:'},
#   'md_keywords': {'keywords': ['actris',
#     'gaw-wdca',
#     'no0042g',
#     'particle_number_size_distribution',
#     'pm10',
#     'zeppelin mountain (ny-ålesund)']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'station': {'identifier': 'ZEP',
#     'name': 'zeppelin_mountain',
#     'lat': 78.90715,
#     'lon': 11.88668,
#     'alt': None,
#     'country_code': 'NO',
#     'wmo_region': 'Europe'}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 11.86,
#    'east_bound_longitude': 11.86,
#    'south_bound_latitude': 79.9,
#    'north_bound_latitude': 79.9},
#   'ex_temporal_extent': {'time_period_begin': '2009-12-31T23:00:00.0000000Z',
#    'time_period_end': '2020-12-31T23:00:00.0000000Z'},
#   'ex_vertical_extent': {'minimum_value': 473.0,
#    'maximum_value': 473.0,
#    'unit_of_measure': 'm above sea level'},
#   'md_content_information': {'attribute_descriptions': ['particle.number.size.distribution'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas/NO0042G.20100101000000.20210621122141.dmps...11y.1h.SE02L_TINTIN.SE02L_DMPS_EUSAAR.lev2.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False, 'description_url': None},
#     'transfersize': None,
#     'description': 'Direct download of data file'}],
#   'md_actris_specific': {'platform_type': 'surface_station',
#    'product_type': 'observation',
#    'matrix': 'Particle',
#    'sub_matrix': 'Unknown',
#    'instrument_type': ['dmps'],
#    'program_affiliation': ['ACTRIS', 'GAW-WDCA'],
#    'legacy_data': True,
#    'data_level': 2,
#    'data_product': 'quality assured data'},
#   'dq_data_quality_information': {'level': 'dataset',
#    'statement': 'Data collected according to instrument specific standard operating procedures, checked on import into data base.',
#    'description': None}}]

# %%
# Each metadata element consists of a dictionary with keys shown in the dropdown menu

dropdown_md_elements = widgets.Dropdown(
    options=list(metadata_archive[0].keys()),
    value=list(metadata_archive[0].keys())[0],
    description='',
    disabled=False,
)

dropdown_md_elements
# Out:
# Dropdown(options=('md_metadata', 'md_identification', 'md_constraints', 'md_keywords', 'md_data_identification…

# %%
# Most of these keys consists of a new dictonary with metadata information. 
# An example is md_metadata, as show below for dmps in Norway. 
md_list = []
for f in metadata_archive:
    md_list.append(f['md_metadata']) 
df_md_metadata = pd.DataFrame.from_records(md_list)

df_md_metadata
# Out:
#          id  provider_id                                    file_identifier  \
# 0    511581           14  NO0042G.20000301000000.20170523103005.dmps.par...
# 1    511703           14  NO0002R.20151217090000.20170504082503.dmps.par...
# 2    511639           14  NO0059G.20160125170000.20170503133502.dmps.par...
# 3    511644           14  NO0059G.20140129180000.20181205100800.dmps.par...
# 4    511648           14  NO0058G.20070218000000.20181205100800.dmps.par...
# 5    511651           14  NO0042G.20160506060000.20170505102504.dmps.par...
# 6   1005679           14  NO0002R.20090710120000.20211213092553.dmps...3...
# 7   1005684           14  NO0002R.20131003090000.20210826200223.dmps...7...
# 8   1005685           14  NO0002R.20131216200000.20211213115154.dmps...1...
# 9   1012230           14  NO0002R.20120101000000.20211220114453.dmps...2...
# 10   789516           14  NO0042G.20100101000000.20210621122141.dmps...1...
#
#    language hierarchy_level                      online_resource  \
# 0        en         dataset  {'linkage': 'http://ebas.nilu.no/'}
# 1        en         dataset  {'linkage': 'http://ebas.nilu.no/'}
# 2        en         dataset  {'linkage': 'http://ebas.nilu.no/'}
# 3        en         dataset  {'linkage': 'http://ebas.nilu.no/'}
# 4        en         dataset  {'linkage': 'http://ebas.nilu.no/'}
# 5        en         dataset  {'linkage': 'http://ebas.nilu.no/'}
# 6        en         dataset  {'linkage': 'http://ebas.nilu.no/'}
# 7        en         dataset  {'linkage': 'http://ebas.nilu.no/'}
# 8        en         dataset  {'linkage': 'http://ebas.nilu.no/'}
# 9        en         dataset  {'linkage': 'http://ebas.nilu.no/'}
# 10       en         dataset  {'linkage': 'http://ebas.nilu.no/'}
#
#                        datestamp                       created  \
# 0   2019-05-14T05:11:37.0000000Z  2021-02-02T11:38:46.0000000Z
# 1   2019-05-14T04:53:52.0000000Z  2021-02-12T15:25:15.0000000Z
# 2   2019-05-14T05:26:15.0000000Z  2021-02-11T14:43:10.0000000Z
# 3   2019-05-14T05:26:21.0000000Z  2021-02-11T14:43:35.0000000Z
# 4   2019-05-14T05:22:20.0000000Z  2021-02-11T14:44:27.0000000Z
# 5   2019-05-14T05:11:08.0000000Z  2021-02-11T14:52:38.0000000Z
# 6   2021-12-13T08:25:53.0000000Z  2021-12-14T08:00:37.0000000Z
# 7   2021-08-26T18:02:23.0000000Z  2021-12-14T08:04:47.0000000Z
# 8   2021-12-13T10:51:54.0000000Z  2021-12-14T08:04:47.0000000Z
# 9   2021-12-20T10:44:53.0000000Z  2021-12-21T08:05:33.0000000Z
# 10  2021-06-21T10:21:41.0000000Z  2021-06-28T14:07:29.0000000Z
#
#                                               contact
# 0   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 1   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 2   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 3   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 4   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 5   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 6   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 7   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 8   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 9   [{'first_name': 'Markus', 'last_name': 'Fiebig...
# 10  [{'first_name': 'Markus', 'last_name': 'Fiebig...

# %%
# Here the column 'contact' includes more information about a contact person for each dataset. 
# As these datasets are all dmps from Norway, the custodian is Markus Fiebig for all. 

contact_list = []
for j in list(df_md_metadata['contact']):
    contact_list.append(j[0])
    
df_contact = pd.DataFrame.from_records(contact_list)

df_contact
# Out:
#    first_name last_name                            organisation_name  \
# 0      Markus    Fiebig  Norwegian Institute for Air Research (NILU)
# 1      Markus    Fiebig  Norwegian Institute for Air Research (NILU)
# 2      Markus    Fiebig  Norwegian Institute for Air Research (NILU)
# 3      Markus    Fiebig  Norwegian Institute for Air Research (NILU)
# 4      Markus    Fiebig  Norwegian Institute for Air Research (NILU)
# 5      Markus    Fiebig  Norwegian Institute for Air Research (NILU)
# 6      Markus    Fiebig  Norwegian Institute for Air Research (NILU)
# 7      Markus    Fiebig  Norwegian Institute for Air Research (NILU)
# 8      Markus    Fiebig  Norwegian Institute for Air Research (NILU)
# 9      Markus    Fiebig  Norwegian Institute for Air Research (NILU)
# 10     Markus    Fiebig  Norwegian Institute for Air Research (NILU)
#
#       role_code country_code    delivery_point address_city  \
# 0   [custodian]           NO  Insituttveien 18      Kjeller
# 1   [custodian]           NO  Insituttveien 18      Kjeller
# 2   [custodian]           NO  Insituttveien 18      Kjeller
# 3   [custodian]           NO  Insituttveien 18      Kjeller
# 4   [custodian]           NO  Insituttveien 18      Kjeller
# 5   [custodian]           NO  Insituttveien 18      Kjeller
# 6   [custodian]           NO  Insituttveien 18      Kjeller
# 7   [custodian]           NO  Insituttveien 18      Kjeller
# 8   [custodian]           NO  Insituttveien 18      Kjeller
# 9   [custodian]           NO  Insituttveien 18      Kjeller
# 10  [custodian]           NO  Insituttveien 18      Kjeller
#
#    administrative_area  postal_code         email     position_name
# 0                Viken         2007  ebas@nilu.no  Senior Scientist
# 1                Viken         2007  ebas@nilu.no  Senior Scientist
# 2                Viken         2007  ebas@nilu.no  Senior Scientist
# 3                Viken         2007  ebas@nilu.no  Senior Scientist
# 4                Viken         2007  ebas@nilu.no  Senior Scientist
# 5                Viken         2007  ebas@nilu.no  Senior Scientist
# 6                Viken         2007  ebas@nilu.no  Senior Scientist
# 7                Viken         2007  ebas@nilu.no  Senior Scientist
# 8                Viken         2007  ebas@nilu.no  Senior Scientist
# 9                Viken         2007  ebas@nilu.no  Senior Scientist
# 10               Viken         2007  ebas@nilu.no  Senior Scientist

# %%
# Another example of extracting metadata, here the distribution information of Norwegian dmps datasets.
# The distribution information includes data format, dataset url, protocol, restrictions and more.

files_list = []
for f in metadata_archive:
    url = f['md_distribution_information'][0]
    files_list.append(url)
    
df_distribution_information = pd.DataFrame.from_records(files_list)
df_distribution_information
# Out:
#    data_format version_data_format  \
# 0       NETCDF                   4
# 1       NETCDF                   4
# 2       NETCDF                   4
# 3       NETCDF                   4
# 4       NETCDF                   4
# 5       NETCDF                   4
# 6       NETCDF                   4
# 7       NETCDF                   4
# 8       NETCDF                   4
# 9       NETCDF                   4
# 10      NETCDF                   4
#
#                                           dataset_url protocol  function  \
# 0   http://thredds.nilu.no/thredds/dodsC/ebas/NO00...  OPeNDAP  download
# 1   http://thredds.nilu.no/thredds/dodsC/ebas/NO00...  OPeNDAP  download
# 2   http://thredds.nilu.no/thredds/dodsC/ebas/NO00...  OPeNDAP  download
# 3   http://thredds.nilu.no/thredds/dodsC/ebas/NO00...  OPeNDAP  download
# 4   http://thredds.nilu.no/thredds/dodsC/ebas/NO00...  OPeNDAP  download
# 5   http://thredds.nilu.no/thredds/dodsC/ebas/NO00...  OPeNDAP  download
# 6   https://thredds.nilu.no/thredds/fileServer/eba...     HTTP  download
# 7   https://thredds.nilu.no/thredds/fileServer/eba...     HTTP  download
# 8   https://thredds.nilu.no/thredds/fileServer/eba...     HTTP  download
# 9   https://thredds.nilu.no/thredds/fileServer/eba...     HTTP  download
# 10  https://thredds.nilu.no/thredds/fileServer/eba...     HTTP  download
#
#                                 restriction transfersize  \
# 0   {'set': False, 'description_url': None}         None
# 1   {'set': False, 'description_url': None}         None
# 2   {'set': False, 'description_url': None}         None
# 3   {'set': False, 'description_url': None}         None
# 4   {'set': False, 'description_url': None}         None
# 5   {'set': False, 'description_url': None}         None
# 6   {'set': False, 'description_url': None}         None
# 7   {'set': False, 'description_url': None}         None
# 8   {'set': False, 'description_url': None}         None
# 9   {'set': False, 'description_url': None}         None
# 10  {'set': False, 'description_url': None}         None
#
#                      description
# 0   Direct download of data file
# 1   Direct download of data file
# 2   Direct download of data file
# 3   Direct download of data file
# 4   Direct download of data file
# 5   Direct download of data file
# 6   Direct download of data file
# 7   Direct download of data file
# 8   Direct download of data file
# 9   Direct download of data file
# 10  Direct download of data file
