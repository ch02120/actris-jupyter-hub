# %% [markdown]
# <img src='https://www.actris.eu/sites/default/files/inline-images/Actris%20logo.png' width=200 align=right>
#
# # ACTRIS DC
# ## Access metadata from one facility

# %%
# import packages

import pandas as pd
import requests
import json
import ipywidgets as widgets

# %%
# get all metadata from station Birkenes II (9cxe) in catalogue 
response = requests.get("https://prod-actris-md.nilu.no/Metadata/facility/9cxe") 
metadata_archive = response.json() 
metadata_archive # show metadata
# Out:
# [{'md_metadata': {'id': 203849,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://localhost:5009/providers/14'},
#    'file_identifier': 'P3HD-KWCT.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2024-06-13T22:00:00.0000000Z',
#    'created': '2024-06-14T08:17:20.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'PM mass at Birkenes II. These measurements are gathered as a part of the following projects NILU, GAW-WDCA, ACTRIS, EMEP_preliminary',
#    'title': 'PM mass at Birkenes II',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Yong',
#      'last_name': 'Lin',
#      'organisation_name': 'NILU',
#      'role_code': ['pointOfContact'],
#      'country_code': 'NO',
#      'email': 'ebas@nilu.no'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'https://doi.org/10.48597/P3HD-KWCT', 'type': 'DOI'},
#    'date': '2024-06-13T22:00:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'license',
#    'use_constraints': 'license',
#    'other_constraints': 'N/A',
#    'data_licence': 'CC-BY-4.0',
#    'metadata_licence': 'CC-BY-4.0',
#    'citation': 'Fiebig, M., NILU, GAW-WDCA, ACTRIS, EMEP_preliminary, 2014-2015, PM mass at Birkenes II, data hosted by EBAS at NILU, DOI: https://doi.org/10.48597/P3HD-KWCT',
#    'acknowledgement': 'Data used in this <study/report/figure/etc.> were accessed from EBAS \n    (https://ebas.nilu.no) hosted by NILU.\nSpecifically, the use included data affiliated with the frameworks: NILU, GAW-WDCA, ACTRIS, EMEP_preliminary.'},
#   'md_keywords': {'keywords': ['actris',
#     'aerosol particle mass concentration',
#     'aerosol particle phase',
#     'atmosphere',
#     'gaw-wdca',
#     'nilu',
#     'optical particle size spectrometer']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': '9cxe',
#     'name': 'Birkenes II',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe',
#     'identifier_type': 'other PID',
#     'uri': 'https://dev-dc.actris.nilu.no/facility/9cxe',
#     'active': True,
#     'actris_national_facility': True,
#     'actris_nf_uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/89',
#     'facility_type': ['observation platform, fixed']}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.252,
#    'east_bound_longitude': 8.252,
#    'south_bound_latitude': 58.38853,
#    'north_bound_latitude': 58.38853},
#   'ex_temporal_extent': {'time_period_begin': '2013-12-31T23:00:00.0000000Z',
#    'time_period_end': '2014-12-31T23:00:00.0000000Z'},
#   'ex_vertical_extent': None,
#   'md_content_information': {'attribute_descriptions': ['aerosol particle mass concentration'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/ebas_doi/P3/HD/KW/P3HD-KWCT.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 2143439.0},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas_doi/P3/HD/KW/P3HD-KWCT.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 2143439.0}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['optical particle size spectrometer'],
#    'program_affiliation': ['ACTRIS', 'GAW-WDCA', 'NILU'],
#    'variable_statistical_property': None,
#    'legacy_data': True,
#    'observation_timeliness': 'scheduled',
#    'data_product': 'full quality control',
#    'instrument_model': 'GRIMM/190'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS legacy'},
#   'provenance': {'software': 'https://git.nilu.no/ebas/ebas-io',
#    'version_history': None}},
#  {'md_metadata': {'id': 203942,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://localhost:5009/providers/14'},
#    'file_identifier': '53FN-YP9K.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2024-06-13T22:00:00.0000000Z',
#    'created': '2024-06-14T08:20:23.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Aerosol_absorption_coefficient at Birkenes II. These measurements are gathered as a part of the following projects GAW-WDCA, ACTRIS, EMEP',
#    'title': 'Aerosol_absorption_coefficient at Birkenes II',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Yong',
#      'last_name': 'Lin',
#      'organisation_name': 'NILU',
#      'role_code': ['pointOfContact'],
#      'country_code': 'NO',
#      'email': 'ebas@nilu.no'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'https://doi.org/10.48597/53FN-YP9K', 'type': 'DOI'},
#    'date': '2024-06-13T22:00:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'license',
#    'use_constraints': 'license',
#    'other_constraints': 'N/A',
#    'data_licence': 'CC-BY-4.0',
#    'metadata_licence': 'CC-BY-4.0',
#    'citation': 'Fiebig, M., GAW-WDCA, ACTRIS, EMEP, 2012-2016, Aerosol_absorption_coefficient at Birkenes II, data hosted by EBAS at NILU, DOI: https://doi.org/10.48597/53FN-YP9K',
#    'acknowledgement': 'Data used in this <study/report/figure/etc.> were accessed from EBAS \n    (https://ebas.nilu.no) hosted by NILU.\nSpecifically, the use included data affiliated with the frameworks: GAW-WDCA, ACTRIS, EMEP.'},
#   'md_keywords': {'keywords': ['actris',
#     'aerosol particle light absorption coefficient',
#     'aerosol particle phase',
#     'atmosphere',
#     'emep',
#     'filter absorption photometer',
#     'gaw-wdca']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': '9cxe',
#     'name': 'Birkenes II',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe',
#     'identifier_type': 'other PID',
#     'uri': 'https://dev-dc.actris.nilu.no/facility/9cxe',
#     'active': True,
#     'actris_national_facility': True,
#     'actris_nf_uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/89',
#     'facility_type': ['observation platform, fixed']}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.252,
#    'east_bound_longitude': 8.252,
#    'south_bound_latitude': 58.38853,
#    'north_bound_latitude': 58.38853},
#   'ex_temporal_extent': {'time_period_begin': '2012-06-26T22:00:00.0000000Z',
#    'time_period_end': '2015-12-31T23:00:00.0000000Z'},
#   'ex_vertical_extent': None,
#   'md_content_information': {'attribute_descriptions': ['aerosol particle light absorption coefficient'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/ebas_doi/53/FN/YP/53FN-YP9K.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 6747025.0},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas_doi/53/FN/YP/53FN-YP9K.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 6747025.0}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['filter absorption photometer'],
#    'program_affiliation': ['ACTRIS', 'EMEP', 'GAW-WDCA'],
#    'variable_statistical_property': None,
#    'legacy_data': True,
#    'observation_timeliness': 'scheduled',
#    'data_product': 'full quality control',
#    'instrument_model': 'Radiance-Research/PSAP-3W'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS legacy'},
#   'provenance': {'software': 'https://git.nilu.no/ebas/ebas-io',
#    'version_history': None}},
#  {'md_metadata': {'id': 204029,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://localhost:5009/providers/14'},
#    'file_identifier': 'PMGD-ZNF6.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2024-06-13T22:00:00.0000000Z',
#    'created': '2024-06-14T08:21:44.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Aerosol_absorption_coefficient at Birkenes II. These measurements are gathered as a part of the following projects NILU, GAW-WDCA, ACTRIS, EMEP',
#    'title': 'Aerosol_absorption_coefficient at Birkenes II',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Yong',
#      'last_name': 'Lin',
#      'organisation_name': 'NILU',
#      'role_code': ['pointOfContact'],
#      'country_code': 'NO',
#      'email': 'ebas@nilu.no'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'https://doi.org/10.48597/PMGD-ZNF6', 'type': 'DOI'},
#    'date': '2024-06-13T22:00:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'license',
#    'use_constraints': 'license',
#    'other_constraints': 'N/A',
#    'data_licence': 'CC-BY-4.0',
#    'metadata_licence': 'CC-BY-4.0',
#    'citation': 'Fiebig, M., Lunder, C., NILU, GAW-WDCA, ACTRIS, EMEP, 2013-2015, Aerosol_absorption_coefficient at Birkenes II, data hosted by EBAS at NILU, DOI: https://doi.org/10.48597/PMGD-ZNF6',
#    'acknowledgement': 'Data used in this <study/report/figure/etc.> were accessed from EBAS \n    (https://ebas.nilu.no) hosted by NILU.\nSpecifically, the use included data affiliated with the frameworks: NILU, GAW-WDCA, ACTRIS, EMEP.'},
#   'md_keywords': {'keywords': ['actris',
#     'aerosol particle light absorption coefficient',
#     'aerosol particle phase',
#     'atmosphere',
#     'emep',
#     'filter absorption photometer',
#     'gaw-wdca',
#     'nilu']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': '9cxe',
#     'name': 'Birkenes II',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe',
#     'identifier_type': 'other PID',
#     'uri': 'https://dev-dc.actris.nilu.no/facility/9cxe',
#     'active': True,
#     'actris_national_facility': True,
#     'actris_nf_uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/89',
#     'facility_type': ['observation platform, fixed']}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.252,
#    'east_bound_longitude': 8.252,
#    'south_bound_latitude': 58.38853,
#    'north_bound_latitude': 58.38853},
#   'ex_temporal_extent': {'time_period_begin': '2012-12-31T23:00:00.0000000Z',
#    'time_period_end': '2014-12-31T23:00:00.0000000Z'},
#   'ex_vertical_extent': None,
#   'md_content_information': {'attribute_descriptions': ['aerosol particle light absorption coefficient'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/ebas_doi/PM/GD/ZN/PMGD-ZNF6.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 1752241.0},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas_doi/PM/GD/ZN/PMGD-ZNF6.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 1752241.0}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['filter absorption photometer'],
#    'program_affiliation': ['ACTRIS', 'EMEP', 'GAW-WDCA', 'NILU'],
#    'variable_statistical_property': None,
#    'legacy_data': True,
#    'observation_timeliness': 'scheduled',
#    'data_product': 'full quality control',
#    'instrument_model': 'Radiance-Research/PSAP-1W'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS legacy'},
#   'provenance': {'software': 'https://git.nilu.no/ebas/ebas-io',
#    'version_history': None}},
#  {'md_metadata': {'id': 204030,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://localhost:5009/providers/14'},
#    'file_identifier': 'TAWF-MFDW.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2024-06-13T22:00:00.0000000Z',
#    'created': '2024-06-14T08:21:45.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Aerosol_absorption_coefficient at Birkenes II. These measurements are gathered as a part of the following projects NILU, GAW-WDCA, ACTRIS, EMEP',
#    'title': 'Aerosol_absorption_coefficient at Birkenes II',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Yong',
#      'last_name': 'Lin',
#      'organisation_name': 'NILU',
#      'role_code': ['pointOfContact'],
#      'country_code': 'NO',
#      'email': 'ebas@nilu.no'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'https://doi.org/10.48597/TAWF-MFDW', 'type': 'DOI'},
#    'date': '2024-06-13T22:00:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'license',
#    'use_constraints': 'license',
#    'other_constraints': 'N/A',
#    'data_licence': 'CC-BY-4.0',
#    'metadata_licence': 'CC-BY-4.0',
#    'citation': 'Fiebig, M., NILU, GAW-WDCA, ACTRIS, EMEP, 2014-2015, Aerosol_absorption_coefficient at Birkenes II, data hosted by EBAS at NILU, DOI: https://doi.org/10.48597/TAWF-MFDW',
#    'acknowledgement': 'Data used in this <study/report/figure/etc.> were accessed from EBAS \n    (https://ebas.nilu.no) hosted by NILU.\nSpecifically, the use included data affiliated with the frameworks: NILU, GAW-WDCA, ACTRIS, EMEP.'},
#   'md_keywords': {'keywords': ['actris',
#     'aerosol particle light absorption coefficient',
#     'aerosol particle phase',
#     'atmosphere',
#     'emep',
#     'filter absorption photometer',
#     'gaw-wdca',
#     'nilu']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': '9cxe',
#     'name': 'Birkenes II',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe',
#     'identifier_type': 'other PID',
#     'uri': 'https://dev-dc.actris.nilu.no/facility/9cxe',
#     'active': True,
#     'actris_national_facility': True,
#     'actris_nf_uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/89',
#     'facility_type': ['observation platform, fixed']}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.252,
#    'east_bound_longitude': 8.252,
#    'south_bound_latitude': 58.38853,
#    'north_bound_latitude': 58.38853},
#   'ex_temporal_extent': {'time_period_begin': '2013-12-31T23:00:00.0000000Z',
#    'time_period_end': '2014-12-31T23:00:00.0000000Z'},
#   'ex_vertical_extent': None,
#   'md_content_information': {'attribute_descriptions': ['aerosol particle light absorption coefficient'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/ebas_doi/TA/WF/MF/TAWF-MFDW.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 1989917.0},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas_doi/TA/WF/MF/TAWF-MFDW.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 1989917.0}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['filter absorption photometer'],
#    'program_affiliation': ['ACTRIS', 'EMEP', 'GAW-WDCA', 'NILU'],
#    'variable_statistical_property': None,
#    'legacy_data': True,
#    'observation_timeliness': 'scheduled',
#    'data_product': 'full quality control',
#    'instrument_model': 'Radiance-Research/PSAP-3W'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS legacy'},
#   'provenance': {'software': 'https://git.nilu.no/ebas/ebas-io',
#    'version_history': None}},
#  {'md_metadata': {'id': 204051,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://localhost:5009/providers/14'},
#    'file_identifier': 'C79R-5GSD.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2024-06-13T22:00:00.0000000Z',
#    'created': '2024-06-14T08:22:05.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Aerosol_absorption_coefficient at Birkenes II. These measurements are gathered as a part of the following projects NILU, GAW-WDCA, ACTRIS, EMEP',
#    'title': 'Aerosol_absorption_coefficient at Birkenes II',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Yong',
#      'last_name': 'Lin',
#      'organisation_name': 'NILU',
#      'role_code': ['pointOfContact'],
#      'country_code': 'NO',
#      'email': 'ebas@nilu.no'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'https://doi.org/10.48597/C79R-5GSD', 'type': 'DOI'},
#    'date': '2024-06-13T22:00:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'license',
#    'use_constraints': 'license',
#    'other_constraints': 'N/A',
#    'data_licence': 'CC-BY-4.0',
#    'metadata_licence': 'CC-BY-4.0',
#    'citation': 'Fiebig, M., Lunder, C., NILU, GAW-WDCA, ACTRIS, EMEP, 2015-2016, Aerosol_absorption_coefficient at Birkenes II, data hosted by EBAS at NILU, DOI: https://doi.org/10.48597/C79R-5GSD',
#    'acknowledgement': 'Data used in this <study/report/figure/etc.> were accessed from EBAS \n    (https://ebas.nilu.no) hosted by NILU.\nSpecifically, the use included data affiliated with the frameworks: NILU, GAW-WDCA, ACTRIS, EMEP.'},
#   'md_keywords': {'keywords': ['actris',
#     'aerosol particle light absorption coefficient',
#     'aerosol particle phase',
#     'atmosphere',
#     'emep',
#     'filter absorption photometer',
#     'gaw-wdca',
#     'nilu']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': '9cxe',
#     'name': 'Birkenes II',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe',
#     'identifier_type': 'other PID',
#     'uri': 'https://dev-dc.actris.nilu.no/facility/9cxe',
#     'active': True,
#     'actris_national_facility': True,
#     'actris_nf_uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/89',
#     'facility_type': ['observation platform, fixed']}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.252,
#    'east_bound_longitude': 8.252,
#    'south_bound_latitude': 58.38853,
#    'north_bound_latitude': 58.38853},
#   'ex_temporal_extent': {'time_period_begin': '2014-12-31T23:00:00.0000000Z',
#    'time_period_end': '2015-12-31T23:00:00.0000000Z'},
#   'ex_vertical_extent': None,
#   'md_content_information': {'attribute_descriptions': ['aerosol particle light absorption coefficient'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/ebas_doi/C7/9R/5G/C79R-5GSD.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 1105888.0},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas_doi/C7/9R/5G/C79R-5GSD.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 1105888.0}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['filter absorption photometer'],
#    'program_affiliation': ['ACTRIS', 'EMEP', 'GAW-WDCA', 'NILU'],
#    'variable_statistical_property': None,
#    'legacy_data': True,
#    'observation_timeliness': 'scheduled',
#    'data_product': 'full quality control',
#    'instrument_model': 'Radiance-Research/PSAP-1W'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS legacy'},
#   'provenance': {'software': 'https://git.nilu.no/ebas/ebas-io',
#    'version_history': None}},
#  {'md_metadata': {'id': 204336,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://localhost:5009/providers/14'},
#    'file_identifier': 'PGSV-JU4A.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2024-06-13T22:00:00.0000000Z',
#    'created': '2024-06-14T08:28:30.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Meteorology at Birkenes II. These measurements are gathered as a part of the following projects EMEP',
#    'title': 'Meteorology at Birkenes II',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Yong',
#      'last_name': 'Lin',
#      'organisation_name': 'NILU',
#      'role_code': ['pointOfContact'],
#      'country_code': 'NO',
#      'email': 'ebas@nilu.no'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'https://doi.org/10.48597/PGSV-JU4A', 'type': 'DOI'},
#    'date': '2024-06-13T22:00:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'license',
#    'use_constraints': 'license',
#    'other_constraints': 'N/A',
#    'data_licence': 'CC-BY-4.0',
#    'metadata_licence': 'CC-BY-4.0',
#    'citation': 'Aas, W., EMEP, 2016-2016, Meteorology at Birkenes II, data hosted by EBAS at NILU, DOI: https://doi.org/10.48597/PGSV-JU4A',
#    'acknowledgement': 'Data used in this <study/report/figure/etc.> were accessed from EBAS \n    (https://ebas.nilu.no) hosted by NILU.\nSpecifically, the use included data affiliated with the framework: EMEP.'},
#   'md_keywords': {'keywords': ['air pressure',
#     'air temperature',
#     'atmosphere',
#     'atmospheric state',
#     'emep',
#     'weather sensor']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': '9cxe',
#     'name': 'Birkenes II',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe',
#     'identifier_type': 'other PID',
#     'uri': 'https://dev-dc.actris.nilu.no/facility/9cxe',
#     'active': True,
#     'actris_national_facility': True,
#     'actris_nf_uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/89',
#     'facility_type': ['observation platform, fixed']}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.252,
#    'east_bound_longitude': 8.252,
#    'south_bound_latitude': 58.38853,
#    'north_bound_latitude': 58.38853},
#   'ex_temporal_extent': {'time_period_begin': '2016-03-31T22:00:00.0000000Z',
#    'time_period_end': '2016-12-30T23:00:00.0000000Z'},
#   'ex_vertical_extent': None,
#   'md_content_information': {'attribute_descriptions': ['air pressure',
#     'air temperature'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/ebas_doi/PG/SV/JU/PGSV-JU4A.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 747624.0},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas_doi/PG/SV/JU/PGSV-JU4A.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 747624.0}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'atmospheric state',
#    'sub_matrix': None,
#    'instrument_type': ['weather sensor'],
#    'program_affiliation': ['EMEP'],
#    'variable_statistical_property': None,
#    'legacy_data': True,
#    'observation_timeliness': 'scheduled',
#    'data_product': 'full quality control',
#    'instrument_model': 'Aws'},
#   'dq_data_quality_information': {'compliance': 'other'},
#   'provenance': {'software': 'https://git.nilu.no/ebas/ebas-io',
#    'version_history': None}},
#  {'md_metadata': {'id': 204338,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://localhost:5009/providers/14'},
#    'file_identifier': 'JRZU-XD44.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2024-06-13T22:00:00.0000000Z',
#    'created': '2024-06-14T08:28:32.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Particle_number_size_distribution at Birkenes II. These measurements are gathered as a part of the following projects GAW-WDCA, NILU, ACTRIS, EMEP',
#    'title': 'Particle_number_size_distribution at Birkenes II',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Yong',
#      'last_name': 'Lin',
#      'organisation_name': 'NILU',
#      'role_code': ['pointOfContact'],
#      'country_code': 'NO',
#      'email': 'ebas@nilu.no'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'https://doi.org/10.48597/JRZU-XD44', 'type': 'DOI'},
#    'date': '2024-06-13T22:00:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'license',
#    'use_constraints': 'license',
#    'other_constraints': 'N/A',
#    'data_licence': 'CC-BY-4.0',
#    'metadata_licence': 'CC-BY-4.0',
#    'citation': 'Fiebig, M., GAW-WDCA, NILU, ACTRIS, EMEP, 2010-2017, Particle_number_size_distribution at Birkenes II, data hosted by EBAS at NILU, DOI: https://doi.org/10.48597/JRZU-XD44',
#    'acknowledgement': 'Data used in this <study/report/figure/etc.> were accessed from EBAS \n    (https://ebas.nilu.no) hosted by NILU.\nSpecifically, the use included data affiliated with the frameworks: GAW-WDCA, NILU, ACTRIS, EMEP.'},
#   'md_keywords': {'keywords': ['actris',
#     'aerosol particle number size distribution',
#     'aerosol particle phase',
#     'atmosphere',
#     'emep',
#     'gaw-wdca',
#     'nilu',
#     'optical particle size spectrometer']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': '9cxe',
#     'name': 'Birkenes II',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe',
#     'identifier_type': 'other PID',
#     'uri': 'https://dev-dc.actris.nilu.no/facility/9cxe',
#     'active': True,
#     'actris_national_facility': True,
#     'actris_nf_uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/89',
#     'facility_type': ['observation platform, fixed']}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.252,
#    'east_bound_longitude': 8.252,
#    'south_bound_latitude': 58.38853,
#    'north_bound_latitude': 58.38853},
#   'ex_temporal_extent': {'time_period_begin': '2010-01-13T23:00:00.0000000Z',
#    'time_period_end': '2016-12-31T23:00:00.0000000Z'},
#   'ex_vertical_extent': None,
#   'md_content_information': {'attribute_descriptions': ['aerosol particle number size distribution'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/ebas_doi/JR/ZU/XD/JRZU-XD44.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 95871700.0},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas_doi/JR/ZU/XD/JRZU-XD44.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 95871700.0}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['optical particle size spectrometer'],
#    'program_affiliation': ['ACTRIS', 'EMEP', 'GAW-WDCA', 'NILU'],
#    'variable_statistical_property': None,
#    'legacy_data': True,
#    'observation_timeliness': 'scheduled',
#    'data_product': 'full quality control',
#    'instrument_model': 'GRIMM/190'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS legacy'},
#   'provenance': {'software': 'https://git.nilu.no/ebas/ebas-io',
#    'version_history': None}},
#  {'md_metadata': {'id': 204389,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://localhost:5009/providers/14'},
#    'file_identifier': 'N25F-APDJ.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2024-06-13T22:00:00.0000000Z',
#    'created': '2024-06-14T08:30:19.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Aerosol_absorption_coefficient at Birkenes II. These measurements are gathered as a part of the following projects GAW-WDCA, ACTRIS, EMEP',
#    'title': 'Aerosol_absorption_coefficient at Birkenes II',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Yong',
#      'last_name': 'Lin',
#      'organisation_name': 'NILU',
#      'role_code': ['pointOfContact'],
#      'country_code': 'NO',
#      'email': 'ebas@nilu.no'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'https://doi.org/10.48597/N25F-APDJ', 'type': 'DOI'},
#    'date': '2024-06-13T22:00:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'license',
#    'use_constraints': 'license',
#    'other_constraints': 'N/A',
#    'data_licence': 'CC-BY-4.0',
#    'metadata_licence': 'CC-BY-4.0',
#    'citation': 'Fiebig, M., GAW-WDCA, ACTRIS, EMEP, 2016-2017, Aerosol_absorption_coefficient at Birkenes II, data hosted by EBAS at NILU, DOI: https://doi.org/10.48597/N25F-APDJ',
#    'acknowledgement': 'Data used in this <study/report/figure/etc.> were accessed from EBAS \n    (https://ebas.nilu.no) hosted by NILU.\nSpecifically, the use included data affiliated with the frameworks: GAW-WDCA, ACTRIS, EMEP.'},
#   'md_keywords': {'keywords': ['actris',
#     'aerosol particle light absorption coefficient',
#     'aerosol particle phase',
#     'atmosphere',
#     'emep',
#     'filter absorption photometer',
#     'gaw-wdca']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': '9cxe',
#     'name': 'Birkenes II',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe',
#     'identifier_type': 'other PID',
#     'uri': 'https://dev-dc.actris.nilu.no/facility/9cxe',
#     'active': True,
#     'actris_national_facility': True,
#     'actris_nf_uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/89',
#     'facility_type': ['observation platform, fixed']}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.252,
#    'east_bound_longitude': 8.252,
#    'south_bound_latitude': 58.38853,
#    'north_bound_latitude': 58.38853},
#   'ex_temporal_extent': {'time_period_begin': '2015-12-31T23:00:00.0000000Z',
#    'time_period_end': '2016-12-31T23:00:00.0000000Z'},
#   'ex_vertical_extent': None,
#   'md_content_information': {'attribute_descriptions': ['aerosol particle light absorption coefficient'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/ebas_doi/N2/5F/AP/N25F-APDJ.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 1922862.0},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas_doi/N2/5F/AP/N25F-APDJ.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 1922862.0}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['filter absorption photometer'],
#    'program_affiliation': ['ACTRIS', 'EMEP', 'GAW-WDCA'],
#    'variable_statistical_property': None,
#    'legacy_data': True,
#    'observation_timeliness': 'scheduled',
#    'data_product': 'full quality control',
#    'instrument_model': 'Radiance-Research/PSAP-3W'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS legacy'},
#   'provenance': {'software': 'https://git.nilu.no/ebas/ebas-io',
#    'version_history': None}},
#  {'md_metadata': {'id': 204428,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://localhost:5009/providers/14'},
#    'file_identifier': '4HV8-D26F.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2024-06-13T22:00:00.0000000Z',
#    'created': '2024-06-14T08:30:55.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Aerosol light scattering at Birkenes II. These measurements are gathered as a part of the following projects NILU_internal, ACTRIS',
#    'title': 'Aerosol light scattering at Birkenes II',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Yong',
#      'last_name': 'Lin',
#      'organisation_name': 'NILU',
#      'role_code': ['pointOfContact'],
#      'country_code': 'NO',
#      'email': 'ebas@nilu.no'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'https://doi.org/10.48597/4HV8-D26F', 'type': 'DOI'},
#    'date': '2024-06-13T22:00:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'license',
#    'use_constraints': 'license',
#    'other_constraints': 'N/A',
#    'data_licence': 'CC-BY-4.0',
#    'metadata_licence': 'CC-BY-4.0',
#    'citation': 'Fiebig, M., Lunder, C., NILU_internal, ACTRIS, 2016-2017, Aerosol light scattering at Birkenes II, data hosted by EBAS at NILU, DOI: https://doi.org/10.48597/4HV8-D26F',
#    'acknowledgement': 'Data used in this <study/report/figure/etc.> were accessed from EBAS \n    (https://ebas.nilu.no) hosted by NILU.\nSpecifically, the use included data affiliated with the frameworks: NILU_internal, ACTRIS.'},
#   'md_keywords': {'keywords': ['actris',
#     'aerosol particle light hemispheric backscatter coefficient',
#     'aerosol particle light scattering coefficient',
#     'aerosol particle phase',
#     'atmosphere',
#     'mobility particle size spectrometer']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': '9cxe',
#     'name': 'Birkenes II',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe',
#     'identifier_type': 'other PID',
#     'uri': 'https://dev-dc.actris.nilu.no/facility/9cxe',
#     'active': True,
#     'actris_national_facility': True,
#     'actris_nf_uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/89',
#     'facility_type': ['observation platform, fixed']}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.252,
#    'east_bound_longitude': 8.252,
#    'south_bound_latitude': 58.38853,
#    'north_bound_latitude': 58.38853},
#   'ex_temporal_extent': {'time_period_begin': '2015-12-31T23:00:00.0000000Z',
#    'time_period_end': '2016-12-31T23:00:00.0000000Z'},
#   'ex_vertical_extent': None,
#   'md_content_information': {'attribute_descriptions': ['aerosol particle light hemispheric backscatter coefficient',
#     'aerosol particle light scattering coefficient'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/ebas_doi/4H/V8/D2/4HV8-D26F.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 3239598.0},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas_doi/4H/V8/D2/4HV8-D26F.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 3239598.0}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['mobility particle size spectrometer'],
#    'program_affiliation': ['ACTRIS'],
#    'variable_statistical_property': None,
#    'legacy_data': True,
#    'observation_timeliness': 'scheduled',
#    'data_product': 'full quality control',
#    'instrument_model': 'NILU/DMPSmodel2'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS legacy'},
#   'provenance': {'software': 'https://git.nilu.no/ebas/ebas-io',
#    'version_history': None}},
#  {'md_metadata': {'id': 204497,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://localhost:5009/providers/14'},
#    'file_identifier': 'X64M-5JMC.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2024-06-13T22:00:00.0000000Z',
#    'created': '2024-06-14T08:31:59.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'OC/EC at Birkenes II. These measurements are gathered as a part of the following projects NILU, GAW-WDCA, ACTRIS, EMEP',
#    'title': 'OC/EC at Birkenes II',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Yong',
#      'last_name': 'Lin',
#      'organisation_name': 'NILU',
#      'role_code': ['pointOfContact'],
#      'country_code': 'NO',
#      'email': 'ebas@nilu.no'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'https://doi.org/10.48597/X64M-5JMC', 'type': 'DOI'},
#    'date': '2024-06-13T22:00:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'license',
#    'use_constraints': 'license',
#    'other_constraints': 'N/A',
#    'data_licence': 'CC-BY-4.0',
#    'metadata_licence': 'CC-BY-4.0',
#    'citation': 'Yttri, K., NILU, GAW-WDCA, ACTRIS, EMEP, 2012-2013, OC/EC at Birkenes II, data hosted by EBAS at NILU, DOI: https://doi.org/10.48597/X64M-5JMC',
#    'acknowledgement': 'Data used in this <study/report/figure/etc.> were accessed from EBAS \n    (https://ebas.nilu.no) hosted by NILU.\nSpecifically, the use included data affiliated with the frameworks: NILU, GAW-WDCA, ACTRIS, EMEP.'},
#   'md_keywords': {'keywords': ['actris',
#     'aerosol particle elemental carbon mass concentration',
#     'aerosol particle organic carbon mass concentration',
#     'aerosol particle phase',
#     'aerosol particle total carbon mass concentration',
#     'atmosphere',
#     'emep',
#     'gaw-wdca',
#     'low volume sampler',
#     'nilu']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': '9cxe',
#     'name': 'Birkenes II',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe',
#     'identifier_type': 'other PID',
#     'uri': 'https://dev-dc.actris.nilu.no/facility/9cxe',
#     'active': True,
#     'actris_national_facility': True,
#     'actris_nf_uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/89',
#     'facility_type': ['observation platform, fixed']}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.252,
#    'east_bound_longitude': 8.252,
#    'south_bound_latitude': 58.38853,
#    'north_bound_latitude': 58.38853},
#   'ex_temporal_extent': {'time_period_begin': '2012-01-03T23:00:00.0000000Z',
#    'time_period_end': '2013-01-01T23:00:00.0000000Z'},
#   'ex_vertical_extent': None,
#   'md_content_information': {'attribute_descriptions': ['aerosol particle elemental carbon mass concentration',
#     'aerosol particle organic carbon mass concentration',
#     'aerosol particle total carbon mass concentration'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/ebas_doi/X6/4M/5J/X64M-5JMC.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 303217.0},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas_doi/X6/4M/5J/X64M-5JMC.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 303217.0}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['low volume sampler'],
#    'program_affiliation': ['ACTRIS', 'EMEP', 'GAW-WDCA', 'NILU'],
#    'variable_statistical_property': None,
#    'legacy_data': True,
#    'observation_timeliness': 'scheduled',
#    'data_product': 'full quality control',
#    'instrument_model': 'Low vol sampler'},
#   'dq_data_quality_information': {'compliance': 'ACTRIS legacy'},
#   'provenance': {'software': 'https://git.nilu.no/ebas/ebas-io',
#    'version_history': None}},
#  {'md_metadata': {'id': 204498,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://localhost:5009/providers/14'},
#    'file_identifier': '7NE5-3T23.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2024-06-13T22:00:00.0000000Z',
#    'created': '2024-06-14T08:32:00.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'OC/EC at Birkenes II. These measurements are gathered as a part of the following projects NILU, GAW-WDCA, ACTRIS, EMEP',
#    'title': 'OC/EC at Birkenes II',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Yong',
#      'last_name': 'Lin',
#      'organisation_name': 'NILU',
#      'role_code': ['pointOfContact'],
#      'country_code': 'NO',
#      'email': 'ebas@nilu.no'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'https://doi.org/10.48597/7NE5-3T23', 'type': 'DOI'},
#    'date': '2024-06-13T22:00:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'license',
#    'use_constraints': 'license',
#    'other_constraints': 'N/A',
#    'data_licence': 'CC-BY-4.0',
#    'metadata_licence': 'CC-BY-4.0',
#    'citation': 'Yttri, K., NILU, GAW-WDCA, ACTRIS, EMEP, 2013-2014, OC/EC at Birkenes II, data hosted by EBAS at NILU, DOI: https://doi.org/10.48597/7NE5-3T23',
#    'acknowledgement': 'Data used in this <study/report/figure/etc.> were accessed from EBAS \n    (https://ebas.nilu.no) hosted by NILU.\nSpecifically, the use included data affiliated with the frameworks: NILU, GAW-WDCA, ACTRIS, EMEP.'},
#   'md_keywords': {'keywords': ['actris',
#     'aerosol particle elemental carbon mass concentration',
#     'aerosol particle organic carbon mass concentration',
#     'aerosol particle phase',
#     'aerosol particle total carbon mass concentration',
#     'atmosphere',
#     'emep',
#     'gaw-wdca',
#     'low volume sampler',
#     'nilu']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
# ...
#    'north_bound_latitude': 58.38853},
#   'ex_temporal_extent': {'time_period_begin': '2009-12-31T23:00:00.0000000Z',
#    'time_period_end': '2023-12-30T23:00:00.0000000Z'},
#   'ex_vertical_extent': None,
#   'md_content_information': {'attribute_descriptions': ['ozone mass concentration'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/ebas_doi/2Q/QE/CB/2QQE-CBAC.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 6036919.0},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas_doi/2Q/QE/CB/2QQE-CBAC.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 6036919.0}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'gas phase',
#    'sub_matrix': None,
#    'instrument_type': ['ultra-violet fluorescence detector'],
#    'program_affiliation': ['CAMP', 'EMEP', 'NILU'],
#    'variable_statistical_property': None,
#    'legacy_data': True,
#    'observation_timeliness': 'scheduled',
#    'data_product': 'full quality control',
#    'instrument_model': 'Uv abs'},
#   'dq_data_quality_information': {'compliance': 'other'},
#   'provenance': {'software': 'https://git.nilu.no/ebas/ebas-io',
#    'version_history': None}},
#  {'md_metadata': {'id': 238541,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://localhost:5009/providers/14'},
#    'file_identifier': '7UXX-HN4M.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2024-06-14T22:00:00.0000000Z',
#    'created': '2024-06-15T04:02:40.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Hydrogen at Birkenes II. These measurements are gathered as a part of the following projects NILU, EMEP',
#    'title': 'Hydrogen at Birkenes II',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Yong',
#      'last_name': 'Lin',
#      'organisation_name': 'NILU',
#      'role_code': ['pointOfContact'],
#      'country_code': 'NO',
#      'email': 'ebas@nilu.no'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'https://doi.org/10.48597/7UXX-HN4M', 'type': 'DOI'},
#    'date': '2024-06-14T22:00:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'license',
#    'use_constraints': 'license',
#    'other_constraints': 'N/A',
#    'data_licence': 'CC-BY-4.0',
#    'metadata_licence': 'CC-BY-4.0',
#    'citation': 'Lunder, C., NILU, EMEP, 2009-2018, Hydrogen at Birkenes II, data hosted by EBAS at NILU, DOI: https://doi.org/10.48597/7UXX-HN4M',
#    'acknowledgement': 'Data used in this <study/report/figure/etc.> were accessed from EBAS \n    (https://ebas.nilu.no) hosted by NILU.\nSpecifically, the use included data affiliated with the frameworks: NILU, EMEP.'},
#   'md_keywords': {'keywords': ['atmosphere',
#     'emep',
#     'gas chromatograph, online',
#     'gas phase',
#     'hydrogen amount fraction',
#     'nilu']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': '9cxe',
#     'name': 'Birkenes II',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe',
#     'identifier_type': 'other PID',
#     'uri': 'https://dev-dc.actris.nilu.no/facility/9cxe',
#     'active': True,
#     'actris_national_facility': True,
#     'actris_nf_uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/89',
#     'facility_type': ['observation platform, fixed']}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.252,
#    'east_bound_longitude': 8.252,
#    'south_bound_latitude': 58.38853,
#    'north_bound_latitude': 58.38853},
#   'ex_temporal_extent': {'time_period_begin': '2009-09-03T22:00:00.0000000Z',
#    'time_period_end': '2018-12-30T23:00:00.0000000Z'},
#   'ex_vertical_extent': None,
#   'md_content_information': {'attribute_descriptions': ['hydrogen amount fraction'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/ebas_doi/7U/XX/HN/7UXX-HN4M.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 4625049.0},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas_doi/7U/XX/HN/7UXX-HN4M.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 4625049.0}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'gas phase',
#    'sub_matrix': None,
#    'instrument_type': ['gas chromatograph, online'],
#    'program_affiliation': ['EMEP', 'NILU'],
#    'variable_statistical_property': None,
#    'legacy_data': True,
#    'observation_timeliness': 'scheduled',
#    'data_product': 'full quality control',
#    'instrument_model': 'Agilent+NILU/6890N/D-3-I PDHID+NILU_GasInjectionSystem'},
#   'dq_data_quality_information': {'compliance': 'other'},
#   'provenance': {'software': 'https://git.nilu.no/ebas/ebas-io',
#    'version_history': None}},
#  {'md_metadata': {'id': 238643,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://localhost:5009/providers/14'},
#    'file_identifier': '4U9H-3SVA.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2024-06-14T22:00:00.0000000Z',
#    'created': '2024-06-15T04:06:29.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Heavy metals at Birkenes II. These measurements are gathered as a part of the following projects CAMP, NILU, EMEP',
#    'title': 'Heavy metals at Birkenes II',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Yong',
#      'last_name': 'Lin',
#      'organisation_name': 'NILU',
#      'role_code': ['pointOfContact'],
#      'country_code': 'NO',
#      'email': 'ebas@nilu.no'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'https://doi.org/10.48597/4U9H-3SVA', 'type': 'DOI'},
#    'date': '2024-06-14T22:00:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'license',
#    'use_constraints': 'license',
#    'other_constraints': 'N/A',
#    'data_licence': 'CC-BY-4.0',
#    'metadata_licence': 'CC-BY-4.0',
#    'citation': 'Aas, W., CAMP, NILU, EMEP, 2020-2024, Heavy metals at Birkenes II, data hosted by EBAS at NILU, DOI: https://doi.org/10.48597/4U9H-3SVA',
#    'acknowledgement': 'Data used in this <study/report/figure/etc.> were accessed from EBAS \n    (https://ebas.nilu.no) hosted by NILU.\nSpecifically, the use included data affiliated with the frameworks: CAMP, NILU, EMEP.'},
#   'md_keywords': {'keywords': ['aerosol particle aluminium mass concentration',
#     'aerosol particle arsenic mass concentration',
#     'aerosol particle cadmium mass concentration',
#     'aerosol particle chromium mass concentration',
#     'aerosol particle cobalt mass concentration',
#     'aerosol particle copper mass concentration',
#     'aerosol particle iron mass concentration',
#     'aerosol particle lead mass concentration',
#     'aerosol particle manganese mass concentration',
#     'aerosol particle nickel mass concentration',
#     'aerosol particle phase',
#     'aerosol particle titanium mass concentration',
#     'aerosol particle vanadium mass concentration',
#     'aerosol particle zinc mass concentration',
#     'atmosphere',
#     'camp',
#     'emep',
#     'low volume sampler',
#     'nilu']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': '9cxe',
#     'name': 'Birkenes II',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe',
#     'identifier_type': 'other PID',
#     'uri': 'https://dev-dc.actris.nilu.no/facility/9cxe',
#     'active': True,
#     'actris_national_facility': True,
#     'actris_nf_uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/89',
#     'facility_type': ['observation platform, fixed']}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.252,
#    'east_bound_longitude': 8.252,
#    'south_bound_latitude': 58.38853,
#    'north_bound_latitude': 58.38853},
#   'ex_temporal_extent': {'time_period_begin': '2019-12-31T23:00:00.0000000Z',
#    'time_period_end': '2023-12-31T23:00:00.0000000Z'},
#   'ex_vertical_extent': None,
#   'md_content_information': {'attribute_descriptions': ['aerosol particle aluminium mass concentration',
#     'aerosol particle arsenic mass concentration',
#     'aerosol particle cadmium mass concentration',
#     'aerosol particle chromium mass concentration',
#     'aerosol particle cobalt mass concentration',
#     'aerosol particle copper mass concentration',
#     'aerosol particle iron mass concentration',
#     'aerosol particle lead mass concentration',
#     'aerosol particle manganese mass concentration',
#     'aerosol particle nickel mass concentration',
#     'aerosol particle titanium mass concentration',
#     'aerosol particle vanadium mass concentration',
#     'aerosol particle zinc mass concentration'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/ebas_doi/4U/9H/3S/4U9H-3SVA.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 455109.0},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas_doi/4U/9H/3S/4U9H-3SVA.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 455109.0}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'aerosol particle phase',
#    'sub_matrix': None,
#    'instrument_type': ['low volume sampler'],
#    'program_affiliation': ['CAMP', 'EMEP', 'NILU'],
#    'variable_statistical_property': None,
#    'legacy_data': True,
#    'observation_timeliness': 'scheduled',
#    'data_product': 'full quality control',
#    'instrument_model': 'Leckel/LVS3'},
#   'dq_data_quality_information': {'compliance': 'other'},
#   'provenance': {'software': 'https://git.nilu.no/ebas/ebas-io',
#    'version_history': None}},
#  {'md_metadata': {'id': 238651,
#    'provider': {'name': 'IN-SITU',
#     'atom': 'http://localhost:5009/providers/14'},
#    'file_identifier': 'G3PF-542S.nc',
#    'language': 'en',
#    'hierarchy_level': 'dataset',
#    'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#    'datestamp': '2024-06-14T22:00:00.0000000Z',
#    'created': '2024-06-15T04:06:47.0000000Z',
#    'contact': [{'first_name': 'Markus',
#      'last_name': 'Fiebig',
#      'organisation_name': 'NILU',
#      'role_code': ['custodian'],
#      'country_code': 'NO',
#      'delivery_point': 'Instituttveien 18',
#      'address_city': 'Kjeller',
#      'administrative_area': 'Viken',
#      'postal_code': 2007,
#      'email': 'ebas@nilu.no',
#      'position_name': 'Senior Scientist'}]},
#   'md_identification': {'abstract': 'Mercury_GEM at Birkenes II. These measurements are gathered as a part of the following projects CAMP, NILU, EMEP',
#    'title': 'Mercury_GEM at Birkenes II',
#    'date_type': 'creation',
#    'contact': [{'first_name': 'Yong',
#      'last_name': 'Lin',
#      'organisation_name': 'NILU',
#      'role_code': ['pointOfContact'],
#      'country_code': 'NO',
#      'email': 'ebas@nilu.no'}],
#    'online_resource': {'linkage': 'https://ebas-data.nilu.no/'},
#    'identifier': {'pid': 'https://doi.org/10.48597/G3PF-542S', 'type': 'DOI'},
#    'date': '2024-06-14T22:00:00.0000000Z'},
#   'md_constraints': {'access_constraints': 'license',
#    'use_constraints': 'license',
#    'other_constraints': 'N/A',
#    'data_licence': 'CC-BY-4.0',
#    'metadata_licence': 'CC-BY-4.0',
#    'citation': 'Aspmo, K., CAMP, NILU, EMEP, 2011-2024, Mercury_GEM at Birkenes II, data hosted by EBAS at NILU, DOI: https://doi.org/10.48597/G3PF-542S',
#    'acknowledgement': 'Data used in this <study/report/figure/etc.> were accessed from EBAS \n    (https://ebas.nilu.no) hosted by NILU.\nSpecifically, the use included data affiliated with the frameworks: CAMP, NILU, EMEP.'},
#   'md_keywords': {'keywords': ['amalgamation cold vapour atomic fluorescence spectrometer',
#     'atmosphere',
#     'camp',
#     'emep',
#     'gas phase',
#     'gaseous elemental mercury mass concentration',
#     'nilu']},
#   'md_data_identification': {'language': 'en',
#    'topic_category': 'climatologyMeteorologyAtmosphere',
#    'description': 'time series of point measurements at surface',
#    'facility': {'identifier': '9cxe',
#     'name': 'Birkenes II',
#     'lat': 58.38853,
#     'lon': 8.252,
#     'alt': 219.0,
#     'country_code': 'NO',
#     'wmo_region': 'Europe',
#     'identifier_type': 'other PID',
#     'uri': 'https://dev-dc.actris.nilu.no/facility/9cxe',
#     'active': True,
#     'actris_national_facility': True,
#     'actris_nf_uri': 'https://actris-nf-labelling.out.ocp.fmi.fi/facility/89',
#     'facility_type': ['observation platform, fixed']}},
#   'ex_geographic_bounding_box': {'west_bound_longitude': 8.252,
#    'east_bound_longitude': 8.252,
#    'south_bound_latitude': 58.38853,
#    'north_bound_latitude': 58.38853},
#   'ex_temporal_extent': {'time_period_begin': '2010-12-31T23:00:00.0000000Z',
#    'time_period_end': '2023-12-31T23:00:00.0000000Z'},
#   'ex_vertical_extent': None,
#   'md_content_information': {'attribute_descriptions': ['gaseous elemental mercury mass concentration'],
#    'content_type': 'physicalMeasurement'},
#   'md_distribution_information': [{'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/dodsC/ebas_doi/G3/PF/54/G3PF-542S.nc',
#     'protocol': 'OPeNDAP',
#     'function': 'streaming',
#     'restriction': {'set': False},
#     'transfersize': 4208314.0},
#    {'data_format': 'NETCDF',
#     'version_data_format': '4',
#     'dataset_url': 'https://thredds.nilu.no/thredds/fileServer/ebas_doi/G3/PF/54/G3PF-542S.nc',
#     'protocol': 'HTTP',
#     'function': 'download',
#     'restriction': {'set': False},
#     'transfersize': 4208314.0}],
#   'md_actris_specific': {'facility_type': 'observation platform, fixed',
#    'product_type': 'observation',
#    'matrix': 'gas phase',
#    'sub_matrix': None,
#    'instrument_type': ['amalgamation cold vapour atomic fluorescence spectrometer'],
#    'program_affiliation': ['CAMP', 'EMEP', 'NILU'],
#    'variable_statistical_property': None,
#    'legacy_data': True,
#    'observation_timeliness': 'scheduled',
#    'data_product': 'full quality control',
#    'instrument_model': 'Tekran/2537A'},
#   'dq_data_quality_information': {'compliance': 'other'},
#   'provenance': {'software': 'https://git.nilu.no/ebas/ebas-io',
#    'version_history': None}}]

# %%
# Each metadata element consists of a dictionary with keys shown in the dropdown menu

dropdown_md_elements = widgets.Dropdown(
    options=list(metadata_archive[0].keys()),
    value=list(metadata_archive[0].keys())[0],
    description='',
    disabled=False,
)

dropdown_md_elements
# Out:
# Dropdown(options=('md_metadata', 'md_identification', 'md_constraints', 'md_keywords', 'md_data_identification…

# %%
metadata_archive[0][dropdown_md_elements.value]
# Out:
# {'id': 203849,
#  'provider': {'name': 'IN-SITU', 'atom': 'http://localhost:5009/providers/14'},
#  'file_identifier': 'P3HD-KWCT.nc',
#  'language': 'en',
#  'hierarchy_level': 'dataset',
#  'online_resource': {'linkage': 'http://ebas.nilu.no/'},
#  'datestamp': '2024-06-13T22:00:00.0000000Z',
#  'created': '2024-06-14T08:17:20.0000000Z',
#  'contact': [{'first_name': 'Markus',
#    'last_name': 'Fiebig',
#    'organisation_name': 'NILU',
#    'role_code': ['custodian'],
#    'country_code': 'NO',
#    'delivery_point': 'Instituttveien 18',
#    'address_city': 'Kjeller',
#    'administrative_area': 'Viken',
#    'postal_code': 2007,
#    'email': 'ebas@nilu.no',
#    'position_name': 'Senior Scientist'}]}

# %%
# Most of these keys consists of a new dictonary with metadata information. 
# An example is md_metadata 
md_list = []
for f in metadata_archive:
    md_list.append(f['md_metadata']) 
df_md_metadata = pd.DataFrame.from_records(md_list)

df_md_metadata.iloc[0] #only show first element in list of metadata
# Out:
# id                                                            203849
# provider           {'name': 'IN-SITU', 'atom': 'http://localhost:...
# file_identifier                                         P3HD-KWCT.nc
# language                                                          en
# hierarchy_level                                              dataset
# online_resource                  {'linkage': 'http://ebas.nilu.no/'}
# datestamp                               2024-06-13T22:00:00.0000000Z
# created                                 2024-06-14T08:17:20.0000000Z
# contact            [{'first_name': 'Markus', 'last_name': 'Fiebig...
# Name: 0, dtype: object

# %%
# Above the column 'contact' includes more information about a contact person for each dataset. 

df_md_metadata.iloc[0]['contact'] # show contact information for first dataset
# Out:
# [{'first_name': 'Markus',
#   'last_name': 'Fiebig',
#   'organisation_name': 'NILU',
#   'role_code': ['custodian'],
#   'country_code': 'NO',
#   'delivery_point': 'Instituttveien 18',
#   'address_city': 'Kjeller',
#   'administrative_area': 'Viken',
#   'postal_code': 2007,
#   'email': 'ebas@nilu.no',
#   'position_name': 'Senior Scientist'}]

# %%
# Another example of extracting metadata, here the content information.
files_list = []
for f in metadata_archive:
    url = f['md_content_information']
    files_list.append(url)
    
df_content_information = pd.DataFrame.from_records(files_list)
# Displays the content information for all datasets from Birkenes II 
df_content_information
# Out:
#                                 attribute_descriptions         content_type
# 0                [aerosol particle mass concentration]  physicalMeasurement
# 1      [aerosol particle light absorption coefficient]  physicalMeasurement
# 2      [aerosol particle light absorption coefficient]  physicalMeasurement
# 3      [aerosol particle light absorption coefficient]  physicalMeasurement
# 4      [aerosol particle light absorption coefficient]  physicalMeasurement
# ..                                                 ...                  ...
# 105  [aerosol particle elemental carbon mass concen...  physicalMeasurement
# 106                         [ozone mass concentration]  physicalMeasurement
# 107                         [hydrogen amount fraction]  physicalMeasurement
# 108  [aerosol particle aluminium mass concentration...  physicalMeasurement
# 109     [gaseous elemental mercury mass concentration]  physicalMeasurement
#
# [110 rows x 2 columns]

# %%
# Another example of extracting metadata, here the distribution information.
# The distribution information includes data format, dataset url, protocol, restrictions and more.

files_list = []
for f in metadata_archive:
    url = f['md_distribution_information'][0]
    files_list.append(url)
    
df_distribution_information = pd.DataFrame.from_records(files_list)
df_distribution_information.iloc[0] #show the distribution information for the first dataset. 
# If you wish to see distribution information about all Birkenes II datasets, remove .iloc[0]
# Out:
# data_format                                                       NETCDF
# version_data_format                                                    4
# dataset_url            https://thredds.nilu.no/thredds/dodsC/ebas_doi...
# protocol                                                         OPeNDAP
# function                                                       streaming
# restriction                                               {'set': False}
# transfersize                                                   2143439.0
# Name: 0, dtype: object
