# %%
# Importing useful python libraries
import xarray as xr 
import threddsclient
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 
import datetime
import os

# %%
# Get the EBAS thredds catalog
all_opendap_urls = threddsclient.opendap_urls('https://thredds.nilu.no/thredds/catalog/ebas/catalog.html')

# %%
opendap_urls = [x for x in all_opendap_urls if 'NO0002' in x]
inst_opendap_urls = [x for x in opendap_urls if 'nephelometer' in x]

# %%
# Get the list of all the files
# Create an empty list to store the datasets
datasets = []

# Loop through each URL and open the dataset
for url in inst_opendap_urls:
    ds = xr.open_dataset(url)
    # Append the dataset to the list
    datasets.append(ds)

# %%
ds = datasets[0]

# %%
ds.aerosol_light_backscattering_coefficient_amean_qc
# Out:
# <xarray.DataArray 'aerosol_light_backscattering_coefficient_amean_qc' (
#                                                                        Wavelength: 3,
#                                                                        aerosol_light_backscattering_coefficient_amean_qc_flags: 3,
#                                                                        time: 113952)>
# [1025568 values with dtype=float64]
# Coordinates:
#   * time        (time) datetime64[ns] 2010-01-01T00:30:00 ... 2022-12-31T23:3...
#   * Wavelength  (Wavelength) float64 450.0 550.0 700.0
# Dimensions without coordinates:
#                                 aerosol_light_backscattering_coefficient_amean_qc_flags
# Attributes:
#     standard_name:  status_flag
#     units:          1

# %%
ds.aerosol_light_backscattering_coefficient_amean
# Out:
# <xarray.DataArray 'aerosol_light_backscattering_coefficient_amean' (
#                                                                     Wavelength: 3,
#                                                                     time: 113952)>
# [341856 values with dtype=float64]
# Coordinates:
#   * time        (time) datetime64[ns] 2010-01-01T00:30:00 ... 2022-12-31T23:3...
#   * Wavelength  (Wavelength) float64 450.0 550.0 700.0
# Attributes: (12/42)
#     units:                             1/Mm
#     ancillary_variables:               aerosol_light_backscattering_coefficie...
#     cell_methods:                      time: mean
#     ebas_data_license:                 https://creativecommons.org/licenses/b...
#     ebas_revision_date:                20230623163936
#     ebas_statistics:                   arithmetic mean
#     ...                                ...
#     ebas_framework_name:               European Research Infrastructure for t...
#     ebas_framework_description:        ACTRIS is the European Research Infras...
#     ebas_framework_contact_name:       Cathrine Lund Myhre, Kjetil Tørseth, M...
#     ebas_framework_contact_email:      clm@nilu.no, kt@nilu.no, Markus.Fiebig...
#     ebas_originator:                   Lunder, Chris, crl@nilu.no, Norwegian ...
#     ebas_submitter:                    Lunder, Chris, crl@nilu.no, Norwegian ...
